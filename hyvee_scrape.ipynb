# %% [markdown]
# <a href="https://colab.research.google.com/github/DSPG-2022/DSPG/blob/main/hyvee_scrape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update 
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium
# !pip install kora -q

import sys
sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')
import os
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
#from kora.selenium import wd
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:9 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:10 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:14 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,861 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,294 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [1,006 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [22.8 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,521 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [1,040 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,297 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [29.8 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-backports/main amd64 Packages [12.2 kB]
# Fetched 12.3 MB in 3s (3,637 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 49 not upgraded.
# Need to get 89.8 MB of archives.
# After this operation, 302 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 101.0.4951.64-0ubuntu0.18.04.1 [1,142 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser amd64 101.0.4951.64-0ubuntu0.18.04.1 [78.5 MB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser-l10n all 101.0.4951.64-0ubuntu0.18.04.1 [4,980 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-chromedriver amd64 101.0.4951.64-0ubuntu0.18.04.1 [5,153 kB]
# Fetched 89.8 MB in 4s (23.6 MB/s)
# Selecting previously unselected package chromium-codecs-ffmpeg-extra.
# (Reading database ... 155639 files and directories currently installed.)
# Preparing to unpack .../chromium-codecs-ffmpeg-extra_101.0.4951.64-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-codecs-ffmpeg-extra (101.0.4951.64-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser.
# Preparing to unpack .../chromium-browser_101.0.4951.64-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-browser (101.0.4951.64-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser-l10n.
# Preparing to unpack .../chromium-browser-l10n_101.0.4951.64-0ubuntu0.18.04.1_all.deb ...
# Unpacking chromium-browser-l10n (101.0.4951.64-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_101.0.4951.64-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-chromedriver (101.0.4951.64-0ubuntu0.18.04.1) ...
# Setting up chromium-codecs-ffmpeg-extra (101.0.4951.64-0ubuntu0.18.04.1) ...
# Setting up chromium-browser (101.0.4951.64-0ubuntu0.18.04.1) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (101.0.4951.64-0ubuntu0.18.04.1) ...
# Setting up chromium-browser-l10n (101.0.4951.64-0ubuntu0.18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting selenium
#   Downloading selenium-4.2.0-py3-none-any.whl (983 kB)
#      |████████████████████████████████| 983 kB 5.2 MB/s
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Collecting urllib3[secure,socks]~=1.26
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 43.9 MB/s
# Collecting trio~=0.17
#   Downloading trio-0.21.0-py3-none-any.whl (358 kB)
#      |████████████████████████████████| 358 kB 52.0 MB/s
# Collecting outcome
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.1.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Collecting pyOpenSSL>=0.14
#   Downloading pyOpenSSL-22.0.0-py2.py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 3.8 MB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from urllib3[secure,socks]~=1.26->selenium) (2022.6.15)
# Collecting cryptography>=1.3.4
#   Downloading cryptography-37.0.2-cp36-abi3-manylinux_2_24_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 33.7 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium) (2.21)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.13.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 5.7 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from h11<1,>=0.9.0->wsproto>=0.14->trio-websocket~=0.9->selenium) (4.1.1)
# Installing collected packages: sniffio, outcome, h11, cryptography, async-generator, wsproto, urllib3, trio, pyOpenSSL, trio-websocket, selenium
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.9 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed async-generator-1.10 cryptography-37.0.2 h11-0.13.0 outcome-1.2.0 pyOpenSSL-22.0.0 selenium-4.2.0 sniffio-1.2.0 trio-0.21.0 trio-websocket-0.9.2 urllib3-1.26.9 wsproto-1.1.0
#      |████████████████████████████████| 57 kB 2.7 MB/s

# %%
options = webdriver.ChromeOptions()
options.add_argument('--no-sandbox')
options.add_argument('--headless')
options.add_argument('--disable-dev-shm-usage')
#options.add_argument('--incognito')

wd = webdriver.Chrome('chromedriver',options=options)
driver =webdriver.Chrome('chromedriver',options=options)

# open it, go to a website, and get results
wd.get("https://shop.iowafood.coop/product-search?IDSubcat=164")

print(wd.page_source)  # display the html of the page your webdriver is visting

print(wd.current_url)

print(wd.title)
# Out:
# <html lang="en"><head>
# 	<meta charset="utf-8">
# 	<meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
# 	<meta name="robots" content="noindex">
# 	<meta name="csrf-token" content="ZSkbeR3k-kD1nWowmbc8hj54qp_3VjG7pHDA">
#
# 	<title>IFC product search</title>
#
#
# 	<link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css" integrity="sha384-JcKb8q3iqJ61gNV9KGb8thSsNjpSL0n8PARn9HuZOnIxN0hoP+VmmDGMN5t9UJ0Z" crossorigin="anonymous">
#
# 	<link rel="stylesheet" href="/Static/main-14.css">
#
#
# 	<script src="https://code.jquery.com/jquery-3.5.1.min.js" integrity="sha256-9/aliU8dGd2tb6OSsuzixeV4y/faTqgFtohetphbbj0=" crossorigin="anonymous"></script>
#
# 	<script async="" src="https://cdn.jsdelivr.net/npm/popper.js@1.16.1/dist/umd/popper.min.js" integrity="sha384-9/reFTGAW83EW2RDu2S0VKaIzap3H66lZH81PoYlFhbGU+6BZp6G7niu735Sk7lN" crossorigin="anonymous"></script>
#
# 	<script async="" src="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/js/bootstrap.min.js" integrity="sha384-B4gt1jrGC7Jh4AgTPSdUtOBvfO8shuf57BaghqFfPlYxofvL8/KUEfYiJOMMV+rV" crossorigin="anonymous"></script>
#
# 	<script src="https://cdn.jsdelivr.net/npm/bs-custom-file-input@1.3.4/dist/bs-custom-file-input.min.js" integrity="sha256-e0DUqNhsFAzOlhrWXnMOQwRoqrCRlofpWgyhnrIIaPo=" crossorigin="anonymous"></script>
#
# 	<script>
# 		$(document).ready(function () {
# 			$('[data-toggle="tooltip"]').tooltip();
#
# 			bsCustomFileInput.init();
# 		});
# 	</script>
#
#
# 	<script src="/Static/main-6.js"></script>
#
# 	<script async="" src="https://www.googletagmanager.com/gtag/js?id=G-QKKRX9EPNS"></script>
# 	<script>
# 		window.dataLayer = window.dataLayer || [];
# 		function gtag(){dataLayer.push(arguments);}
# 		gtag('js', new Date());
#
# 		gtag('config', 'G-QKKRX9EPNS');
# 	</script>
# </head>
#
# <body>
#
#
# 	<noscript>
# 		<div class="Flash alert alert-warning mb-0 pt-1 pb-2" role="alert">
# 			This site requires JavaScript! Learn
# 			<a href="https://www.computerhope.com/issues/ch000891.htm"
# 				class="alert-link">how to enable it</a> in your browser.
# 		</div>
# 	</noscript>
#
# 	<div id="WarnIE" class="Flash alert alert-warning mb-0 pt-1 pb-2" role="alert">
# 		<div>
# 			Sorry, this site will not work properly with
# 			<a href="https://www.engadget.com/2019-02-08-microsoft-internet-explorer-technical-debt.html">Internet Explorer</a>!
# 			Please upgrade to a modern, secure browser:
# 		</div>
# 		<ul class="mb-0">
# 			<li>
# 				Google <a href="https://www.google.com/chrome/">Chrome</a>
# 			</li>
# 			<li>
# 				Mozilla <a href="https://www.mozilla.org/en-US/firefox/new/">Firefox</a>
# 			</li>
# 			<li>
# 				Microsoft <a href="https://www.microsoft.com/en-us/edge">Edge</a>
# 			</li>
# 		</ul>
# 	</div>
#
#
#
# 	<header class="d-print-none d-flex align-items-center">
# 		<div id="ColLogo">
# 			<a href="https://iowafood.coop/">
# 				<img class="d-none d-md-inline mr-1" src="/Static/logo-carrot.svg" alt="" height="30" style="position: relative; top: -0.04rem;">
# 			</a>
# 			<a href="https://iowafood.coop/">
# 				<img alt="" src="/Static/logo-text.svg" height="30">
# 			</a>
# 		</div>
#
#
# 		<div id="ColDates" class="flex-grow-1 text-center">
# 			<div class="d-none d-md-block">
# 				Cart closes Jun 26, 2022 11:59 PM
# 			</div>
#
# 			<div class="d-none d-md-block">
# 				<a href="https://iowafood.coop/locationshours" target="_blank">
# 					Order Pickup Details
# 				</a>
# 			</div>
#
# 		</div>
#
# 		<div id="LblBtnLogin" class="d-none d-md-block text-right mr-2">
# 			<span style="float:left;">Interested in shopping with us? </span>
# 			<a href="/member-registration">Start free trial!</a>
# 			<br>
# 			<span style="float:left; margin-right:10px;">Want to become a producer? </span>
# 			<a href="mailto:info@iowafood.coop">Email info@iowafood.coop</a>
# 		</div>
#
# 		<div id="ColLogin">
# 			<div class="text-right">
# 				<button type="button" class="btn" data-toggle="modal" data-target="#DlgLogin">Login</button>
# 			</div>
# 		</div>
# 	</header>
#
#
# 	<nav class="navbar navbar-expand-md navbar-dark">
# 		<button class="navbar-toggler" type="button" data-target="#Nav" data-toggle="collapse">
# 			<span class="navbar-toggler-icon"></span>
# 		</button>
#
# 		<div id="Nav" class="collapse navbar-collapse">
# 			<ul class="navbar-nav">
#
# 				<li class="nav-item ">
# 					<a href="/" class="nav-link double">
# 						Market
# 						<span class="d-none d-md-inline"><br></span>
# 						Home
# 					</a>
# 				</li>
# 				<li class="nav-item active">
# 					<a href="/product-search" class="nav-link double">
# 						Product
# 						<span class="d-none d-md-inline"><br></span>
# 						Search
# 					</a>
# 				</li>
#
# 			</ul>
# 		</div>
#
# 		<div id="TitleMob" class="d-md-none navbar-brand">
#
# 			Product Search
#
#
#
#
#
#
#
#
# 		</div>
# 	</nav>
#
#
#
#
# 	<div id="Flashes">
# 	</div>
#
#
# 	<div id="DlgLogin" class="modal" tabindex="-1" role="dialog">
# 		<div class="modal-dialog modal-dialog-centered">
# 			<div class="modal-content">
# 				<form action="/login" method="POST" onsubmit="Disab_Form()">
# 					<input type="hidden" name="_csrf" value="ZSkbeR3k-kD1nWowmbc8hj54qp_3VjG7pHDA">
#
# 					<div class="modal-body">
# 						<div class="form-group">
# 							<label for="NameLogin">Username</label>
# 							<input id="NameLogin" name="NameLogin" type="text" required="" minlength="1" class="form-control">
# 						</div>
#
# 						<div class="form-group">
# 							<label for="Pass">Password</label>
# 							<input id="Pass" name="Pass" type="password" required="" minlength="1" class="form-control">
# 						</div>
# 					</div>
#
# 					<div class="modal-footer">
# 						<a href="/request-password-reset">
# 							Forgot your password?
# 						</a>
# 						<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgLogin">
# 							Cancel
# 						</button>
# 						<button type="submit" class="btn btn-primary">
# 							Login
# 						</button>
# 					</div>
# 				</form>
# 			</div>
# 		</div>
# 	</div>
#
#
#
#
# 	<main>
# 		<style>
# 	body {
# 		/*background: linear-gradient(120deg, hsla(66, 30%, 80%, 0.5),
# 			hsla(66, 30%, 80%, 0) 70.71%);*/
# 	}
# </style>
#
# <div class="container py-4">
# 	<form class="form-inline px-1 mb-2" action="/product-search" method="POST" onsubmit="Disab_Form()">
#
# 		<input type="hidden" name="_csrf" value="ZSkbeR3k-kD1nWowmbc8hj54qp_3VjG7pHDA">
#
# 		<input id="Terms" name="Terms" type="text" value="" autofocus="" class="form-control flex-grow-1 mr-sm-2">
#
# 		<div class="d-flex">
# 			<button type="submit" class="btn btn-primary mt-2 mt-sm-0">
# 				<img src="/Static/search.svg" alt="" width="20" height="20" class="IconBtn" style="position: relative; top: -2px">
# 				Search
# 			</button>
#
# 		</div>
# 	</form>
#
# 	<div class="d-sm-flex flex-row px-1 my-3">
# 		<div class="lead">
# 			Subcategory:
# 			<strong>Kale</strong>
# 		</div>
# 		<p class="lead ml-auto mb-0">
# 			12 matches found
# 		</p>
# 	</div>
#
#
# <div class="row row-cols-1 row-cols-sm-2 row-cols-lg-3 no-gutters">
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/14383">
# 						Red Kale
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/238">
# 						Lee's Greens, LLC
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct14383" data-toggle="modal">
#
# 				<hr class="mx-0 mt-0 mb-2">
# 				<div class="Descrip">Fresh cut red kale half lb bags, great for fresh eating.</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct14383" data-toggle="modal">
#
# 				<hr class="mx-0 mt-0 mb-2">
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>half pound bag, Red russian kale</div>
# 						<div>$5.75</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/7986">
# 						Blue Curled Scotch Kale
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/299">
# 						Simon's Plant Collaboration
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct7986" data-toggle="modal">
#
# 				<div style="background-image: url('/StoreImg/A5B5MWA9NNHX.jpg');" class="Img rounded rounded-lg">
# 				</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct7986" data-toggle="modal">
#
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>bag</div>
# 						<div>$3.50</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/12294">
# 						Green Kale
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/228">
# 						Joyful Greens
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct12294" data-toggle="modal">
#
# 				<div style="background-image: url('/StoreImg/SBYK51EW02NZ.jpg');" class="Img rounded rounded-lg">
# 				</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct12294" data-toggle="modal">
#
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>bunch</div>
# 						<div>$2.50</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/13846">
# 						Dinosaur Kale
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/228">
# 						Joyful Greens
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct13846" data-toggle="modal">
#
# 				<div style="background-image: url('/StoreImg/ZC0PNB1ZQ35E.jpg');" class="Img rounded rounded-lg">
# 				</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct13846" data-toggle="modal">
#
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>bunch</div>
# 						<div>$3.00</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/8521">
# 						Curly Green Kale New crop
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/287">
# 						Red Barn Produce
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct8521" data-toggle="modal">
#
# 				<div style="background-image: url('/StoreImg/43V34MPLXXT0.jpg');" class="Img rounded rounded-lg">
# 				</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct8521" data-toggle="modal">
#
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>bag</div>
# 						<div>$3.25</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/6483">
# 						Red Russian Kale - Baby Leaf
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/299">
# 						Simon's Plant Collaboration
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct6483" data-toggle="modal">
#
# 				<div style="background-image: url('/StoreImg/0DMQG6XRR62S.jpg');" class="Img rounded rounded-lg">
# 				</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct6483" data-toggle="modal">
#
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>bag</div>
# 						<div>$4.00</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/6548">
# 						Kale: Dinosaur
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/137">
# 						Eating Well Farm
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct6548" data-toggle="modal">
#
# 				<div style="background-image: url('/StoreImg/SG2QMPER4WTH.jpg');" class="Img rounded rounded-lg">
# 				</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct6548" data-toggle="modal">
#
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>bag</div>
# 						<div>$3.00</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/6550">
# 						Kale: Scarlet
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/137">
# 						Eating Well Farm
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct6550" data-toggle="modal">
#
# 				<div style="background-image: url('/StoreImg/F6PVV08GJ62Q.jpg');" class="Img rounded rounded-lg">
# 				</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct6550" data-toggle="modal">
#
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>bag</div>
# 						<div>$3.00</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/8004">
# 						Kale: Blue Curled Scotch
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/137">
# 						Eating Well Farm
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct8004" data-toggle="modal">
#
# 				<div style="background-image: url('/StoreImg/QHJ3WAL436XJ.jpg');" class="Img rounded rounded-lg">
# 				</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct8004" data-toggle="modal">
#
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>bag</div>
# 						<div>$3.00</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			CornerBtmLeft3 ">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/8434">
# 						AG Blue Dwarf Curly Kale
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/176">
# 						Early Morning Harvest
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct8434" data-toggle="modal">
#
# 				<div style="background-image: url('/StoreImg/A4SYZ3KGKNT2.jpg');" class="Img rounded rounded-lg">
# 				</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct8434" data-toggle="modal">
#
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>bag</div>
# 						<div>$3.00</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			CornerBtmLeft2 ">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/8627">
# 						AG Tascano Kale
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/176">
# 						Early Morning Harvest
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct8627" data-toggle="modal">
#
# 				<div style="background-image: url('/StoreImg/JPXK43Z9MQAK.jpg');" class="Img rounded rounded-lg">
# 				</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct8627" data-toggle="modal">
#
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>bunch</div>
# 						<div>$3.00</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			CornerBtmRight2 CornerBtmRight3 ">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/1825">
# 						Red Russian Kale - 1-lb. bunch
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/86">
# 						Raccoon Forks Farms
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct1825" data-toggle="modal">
#
# 				<div style="background-image: url('/StoreImg/TUWDAPPDSB72.jpg');" class="Img rounded rounded-lg">
# 				</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct1825" data-toggle="modal">
#
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>1-lb. bunch</div>
# 						<div>$5.50</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# </div>
# 	<div class="d-flex flex-row mt-3 pl-1">
# 	</div>
# </div>
#
#
# <div id="DlgDtlProduct14383" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/14383">Red Kale</a><br>
#
# Product 014383
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/238" class="font-weight-semi">
# 							Lee's Greens, LLC
# 						</a><br>
#
# Producer 0238 'lg704'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct14383">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/LZDYGJGW6SPU.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
#
#
#
#
#
#
# 	<a href="/product-search?CkNaturGrownSelf=true">Naturally grown</a>
# 	<a href="/product-search?CkIntegPestMgmtSelf=true">Integrated Pest Management</a>
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty15596" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0015596 half pound bag, Red russian kale
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$5.75
# 	</div>
# 	<div class="col text-right">
# 		2<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>Fresh cut red kale half lb bags, great for fresh eating.</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct14383">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <div id="DlgDtlProduct7986" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/7986">Blue Curled Scotch Kale</a><br>
#
# Product 007986
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/299" class="font-weight-semi">
# 							Simon's Plant Collaboration
# 						</a><br>
#
# Producer 0299 'sim14'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct7986">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/A5B5MWA9NNHX.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
#
#
#
#
#
# 	<a href="/product-search?CkNaturGrownCert=true">Certified Naturally Grown</a>
#
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty9008" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0009008 bag
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$3.50
# 	</div>
# 	<div class="col text-right">
# 		27<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>This variety of kale has curly, blue-green, tender (and delicious!) leaves. Each bag contains about 8 ounces.</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct7986">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <div id="DlgDtlProduct12294" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/12294">Green Kale</a><br>
#
# Product 012294
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/228" class="font-weight-semi">
# 							Joyful Greens
# 						</a><br>
#
# Producer 0228 'joyfl'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct12294">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/SBYK51EW02NZ.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
#
#
#
#
#
# 	<a href="/product-search?CkNaturGrownCert=true">Certified Naturally Grown</a>
#
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty13248" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0013248 bunch
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$2.50
# 	</div>
# 	<div class="col text-right">
# 		30<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>This Leafy herbaceous biennial vegetable is Sweet with an earthy bitterness flavor. It is a great addition to your favorite salad dish or pot of soup.</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct12294">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <div id="DlgDtlProduct13846" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/13846">Dinosaur Kale</a><br>
#
# Product 013846
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/228" class="font-weight-semi">
# 							Joyful Greens
# 						</a><br>
#
# Producer 0228 'joyfl'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct13846">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/ZC0PNB1ZQ35E.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
#
#
#
#
#
# 	<a href="/product-search?CkNaturGrownCert=true">Certified Naturally Grown</a>
#
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty14799" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0014799 bunch
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$3.00
# 	</div>
# 	<div class="col text-right">
# 		25<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>Dinosaur kale is a dark green leafy vegetable. The leaves are so hearty that, even when well-cooked, they retain a wonderful firm texture, making them a great choice for braising or adding to stews.</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct13846">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <div id="DlgDtlProduct8521" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/8521">Curly Green Kale New crop</a><br>
#
# Product 008521
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/287" class="font-weight-semi">
# 							Red Barn Produce
# 						</a><br>
#
# Producer 0287 'rbarn'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct8521">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/43V34MPLXXT0.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
#
#
#
#
#
#
# 	<a href="/product-search?CkNaturGrownSelf=true">Naturally grown</a>
#
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty9537" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0009537 bag
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$3.25
# 	</div>
# 	<div class="col text-right">
# 		6<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>Young curly kale.  Washed and bagged in 8 oz bag. Variety is Vates Curly. Great for soups,salads,in scrambled eggs, or in salads. Grown chemical free in our hoophouse.</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct8521">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <div id="DlgDtlProduct6483" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/6483">Red Russian Kale - Baby Leaf</a><br>
#
# Product 006483
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/299" class="font-weight-semi">
# 							Simon's Plant Collaboration
# 						</a><br>
#
# Producer 0299 'sim14'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct6483">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/0DMQG6XRR62S.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
#
#
#
#
#
# 	<a href="/product-search?CkNaturGrownCert=true">Certified Naturally Grown</a>
#
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty7528" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0007528 bag
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$4.00
# 	</div>
# 	<div class="col text-right">
# 		13<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>This tender, red stemmed kale is tasty in salads or lightly cooked. Each bag contains approximately 8 ounces of baby leaf kale.</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct6483">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <div id="DlgDtlProduct6548" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/6548">Kale: Dinosaur</a><br>
#
# Product 006548
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/137" class="font-weight-semi">
# 							Eating Well Farm
# 						</a><br>
#
# Producer 0137 'Biz14'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct6548">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/SG2QMPER4WTH.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
#
#
#
#
#
# 	<a href="/product-search?CkNaturGrownCert=true">Certified Naturally Grown</a>
#
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty7593" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0007593 bag
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$3.00
# 	</div>
# 	<div class="col text-right">
# 		8<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>Lacinato, or Dinosaur, Kale has a softer texture than curly kale and is great in raw kale salads. Each bag weighs about 8 ounces.</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct6548">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <div id="DlgDtlProduct6550" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/6550">Kale: Scarlet</a><br>
#
# Product 006550
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/137" class="font-weight-semi">
# 							Eating Well Farm
# 						</a><br>
#
# Producer 0137 'Biz14'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct6550">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/F6PVV08GJ62Q.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
#
#
#
#
#
# 	<a href="/product-search?CkNaturGrownCert=true">Certified Naturally Grown</a>
#
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty7595" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0007595 bag
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$3.00
# 	</div>
# 	<div class="col text-right">
# 		9<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>This open-pollinated variety of kale is beautiful as well as delicious! Each bag will contain about 8 ounces of Scarlet kale.</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct6550">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <div id="DlgDtlProduct8004" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/8004">Kale: Blue Curled Scotch</a><br>
#
# Product 008004
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/137" class="font-weight-semi">
# 							Eating Well Farm
# 						</a><br>
#
# Producer 0137 'Biz14'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct8004">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/QHJ3WAL436XJ.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
#
#
#
#
#
# 	<a href="/product-search?CkNaturGrownCert=true">Certified Naturally Grown</a>
#
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty9026" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0009026 bag
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$3.00
# 	</div>
# 	<div class="col text-right">
# 		10<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>This variety of kale has curly, blue-green, tender (and delicious!) leaves. Each bag contains about 8 ounces.</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct8004">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <div id="DlgDtlProduct8434" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/8434">AG Blue Dwarf Curly Kale</a><br>
#
# Product 008434
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/176" class="font-weight-semi">
# 							Early Morning Harvest
# 						</a><br>
#
# Producer 0176 'emh-1'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct8434">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/A4SYZ3KGKNT2.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
# 	<a href="/product-search?CkVegan=true">Vegan</a>
#
#
#
#
# 	<a href="/product-search?CkNaturGrownSelf=true">Naturally grown</a>
#
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty9451" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0009451 bag
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$3.00
# 	</div>
# 	<div class="col text-right">
# 		3<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>Green curled and ruffled leaves for garnish or eating. May have some imperfections as we use no herbicides, pesticides, or chemicals in our greenhouse.</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct8434">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <div id="DlgDtlProduct8627" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/8627">AG Tascano Kale</a><br>
#
# Product 008627
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/176" class="font-weight-semi">
# 							Early Morning Harvest
# 						</a><br>
#
# Producer 0176 'emh-1'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct8627">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/JPXK43Z9MQAK.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
# 	<a href="/product-search?CkVegan=true">Vegan</a>
#
#
#
#
# 	<a href="/product-search?CkNaturGrownSelf=true">Naturally grown</a>
#
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty9643" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0009643 bunch
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$3.00
# 	</div>
# 	<div class="col text-right">
# 		3<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>Extra dark green, noncurled.  Rich, tender leaves have a soft texture.  Italian heirloom. May have some imperfections as we use no herbicides, pesticides, or chemicals in our greenhouse.</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct8627">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <div id="DlgDtlProduct1825" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/1825">Red Russian Kale - 1-lb. bunch</a><br>
#
# Product 001825
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/86" class="font-weight-semi">
# 							Raccoon Forks Farms
# 						</a><br>
#
# Producer 0086 '59907'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct1825">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/TUWDAPPDSB72.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
#
#
#
#
#
#
# 	<a href="/product-search?CkNaturGrownSelf=true">Naturally grown</a>
#
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty16449" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0016449 1-lb. bunch
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$5.50
# 	</div>
# 	<div class="col text-right">
# 		9<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>Delicious dark green leaves with violet veining.  Wonderful raw and cooked - great in salads, soups, stir-fries, and smoothies!</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct1825">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# 	</main>
#
#
# 	<footer class="page-footer p-3 bg-dark text-light">
# 		<div class="d-sm-flex">
# 			<div class="d-none d-sm-block pl-1 pt-1">
# 				<a href="https://iowafood.coop/">
# 					<img class="Seal" src="/Static/logo-seal-mono.svg" alt="" width="120">
# 				</a>
# 			</div>
#
# 			<div class="flex-grow-1 ml-sm-4 mr-4">
# 				<address class="mb-sm-0">
# 					<span class="text-uppercase font-size-110">Iowa Food Cooperative</span><br>
# 					4944 Franklin Ave, Suite G<br>
# 					Des Moines, IA 50310<br>
# 					<a href="tel:+1(515)978-1034">(515)978-1034</a><br>
# 					<a href="mailto:help@iowafood.coop" target="_top">
# 						help@iowafood.coop
# 					</a>
# 				</address>
# 			</div>
#
# 			<div class="ml-auto mr-3 mr-md-3">
# 				<div class="text-uppercase font-size-110 mb-1">Links</div>
# 				<div class="d-md-flex">
# 					<div class="mr-md-4">
# 						<a href="https://iowafood.coop/">
# 							IFC Home
# 						</a><br>
# 						<a href="https://iowafood.coop/locationshours/">
# 							Pickup locations
# 						</a><br>
# 						<a href="https://iowafood.coop/ifc-shopping-calendar/">
# 							Shopping calendar
# 						</a>
# 					</div>
# 					<div>
# 						<a href="https://iowafood.coop/member-information-statement/">
# 							Terms of service
# 						</a><br>
# 						<a href="/acknowledgments">
# 							Acknowledgments
# 						</a>
# 						<br>
# 						<a href="/member-registration">
# 							Start free trial!
# 						</a>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</footer>
#
# 	<script>
# 		// Focus the name field when the Login dialog is displayed. 'autofocus' does
# 		// not work there:
# 		$("#DlgLogin").on("shown.bs.modal", function() {
# 			$("#NameLogin").trigger("focus");
# 		});
#
# 		// Shared handlers
# 		// ---------------
# 		// These handlers are re-used throughout the app.
#
# 		$("input.InputQty").on("input", Rem_ChNonQty);
# 		$("input.InputWgt").on("input", Rem_ChNonWgt);
# 	</script>
#
#
# </body></html>
# https://shop.iowafood.coop/product-search?IDSubcat=164
# IFC product search

# %%
#https://selenium-python.readthedocs.io/locating-elements.html

#wait = WebDriverWait(driver, 100)


#wait.until(EC.presence_of_element_located((By.CLASS_NAME, 'search-products__StyledSearchProductCardsContainer-sc-1vuqqvj-0 dsAFBy')))

#elements = wd.find_elements(by=By.XPATH, value="//*[@id='main']/div[2]/div[2]/div[2]/div[2]/div[1]")
elements = wd.find_elements(by=By.XPATH, value="/html/body/main/div[1]/div[2]")

#elements = wd.find_elements(By.CLASS_NAME, "search-products__StyledSearchProductCardsContainer-sc-1vuqqvj-0 dsAFBy")

#elements = wd.find_elements_by_xpath("//*[@class='ad2k81qe' or @class='f9o22wc5' or @class='l9j0dhe7']")

#elements = wd.find_elements(by=By.XPATH, value="//div[@class='ad2k81qe' and @class='f9o22wc5' and @class='l9j0dhe7']")

#elements = wd.find_elements(by=By.XPATH, value="//*[@class='bq4bzpyk' or @class='j83agx80' or @class='btwxx1t3' or @class='lhclo0ds' or @class='jifvfom9' or @class='muag1w35' or @class='dlv3wnog' or @class='enqfppq2' or @class='rl04r1d5']")

#elements = wd.find_elements(by=By.XPATH, value="//*[@class='bq4bzpyk' and @class='j83agx80' and @class='btwxx1t3' and @class='lhclo0ds' and @class='jifvfom9' and @class='muag1w35' and @class='dlv3wnog' and @class='enqfppq2' and @class='rl04r1d5']")

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

html = soup.BeautifulSoup(wd.page_source)

# %%
url = "https://shop.iowafood.coop/product-search?IDSubcat=164"
response = requests.get(url)
#print(response)

html = response.content
print(html)
# Out:
# b'<!DOCTYPE html><html lang="en"><head><meta content="app-id=1401371704" name="apple-itunes-app"/><meta content="app-id=com.hyvee.grocery" name="google-play-app"/><meta content="hy-vee hy vee hyvee grocery food groceries stores retail supermarket super market chain iowa illinois kansas minnesota missouri nebraska south dakota wisconsin midwest floral catering bakery flowers" name="keywords"/><link href="https://172b0f0ebe158dd4e857-60490dee3451547335d9eb6f9bd3cac0.ssl.cf2.rackcdn.com/hy-vee-app-icon-web-appstore-links.png" rel="apple-touch-icon"/><link href="https://172b0f0ebe158dd4e857-60490dee3451547335d9eb6f9bd3cac0.ssl.cf2.rackcdn.com/hy-vee-app-icon-web-appstore-links.png" rel="android-touch-icon"/><link href="https://8e3463198116a37cf901-4c8f9ce7667a46d130eda30090f49466.ssl.cf2.rackcdn.com/images/favicon.ico" rel="icon"/><style type="text/css">.fresnel-container{margin:0;padding:0;}\n@media not all and (min-width:0px) and (max-width:599px){.fresnel-at-mobile{display:none!important;}}\n@media not all and (min-width:600px){.fresnel-at-desktop{display:none!important;}}\n@media not all and (max-width:599px){.fresnel-lessThan-desktop{display:none!important;}}\n@media not all and (min-width:600px){.fresnel-greaterThan-mobile{display:none!important;}}\n@media not all and (min-width:0px){.fresnel-greaterThanOrEqual-mobile{display:none!important;}}\n@media not all and (min-width:600px){.fresnel-greaterThanOrEqual-desktop{display:none!important;}}\n@media not all and (min-width:0px) and (max-width:599px){.fresnel-between-mobile-desktop{display:none!important;}}</style><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><meta name="description" content="Easily order groceries online for curbside pickup or delivery. Pickup is always free with a minimum $24.95 purchase. Aisles Online has thousands of low-price items to choose from, so you can shop your list without ever leaving the house."/><meta property="og:description" content="Easily order groceries online for curbside pickup or delivery. Pickup is always free with a minimum $24.95 purchase. Aisles Online has thousands of low-price items to choose from, so you can shop your list without ever leaving the house."/><meta property="og:site_name" content="Hy-Vee"/><link as="fetch" crossorigin="anonymous" data-testid="user-details-preload" href="/aisles-online/api/user-details" rel="preload"/><title>Hy-Vee Aisles Online Grocery Shopping</title><meta property="og:title" content="Hy-Vee Aisles Online Grocery Shopping"/><meta name="robots" content="index,follow"/><meta name="next-head-count" content="9"/><link rel="preload" href="/aisles-online/_next/static/css/c8567be1e24a2e0c.css" as="style"/><link rel="stylesheet" href="/aisles-online/_next/static/css/c8567be1e24a2e0c.css" data-n-g=""/><link rel="preload" href="/aisles-online/_next/static/css/6889a72415cb03a2.css" as="style"/><link rel="stylesheet" href="/aisles-online/_next/static/css/6889a72415cb03a2.css" data-n-p=""/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="/aisles-online/_next/static/chunks/polyfills-5cd94c89d3acac5f.js"></script><script src="/aisles-online/_next/static/chunks/webpack-05ab1068072e5bc6.js" defer=""></script><script src="/aisles-online/_next/static/chunks/framework-eeba1b405d308ec4.js" defer=""></script><script src="/aisles-online/_next/static/chunks/main-085296005cd4075e.js" defer=""></script><script src="/aisles-online/_next/static/chunks/pages/_app-7076a822db5fcf0b.js" defer=""></script><script src="/aisles-online/_next/static/chunks/418d5933-3c8b7a39282f7751.js" defer=""></script><script src="/aisles-online/_next/static/chunks/8901-bf63b8f1ebe3246f.js" defer=""></script><script src="/aisles-online/_next/static/chunks/5143-fff019b8503e53b3.js" defer=""></script><script src="/aisles-online/_next/static/chunks/4429-4bed98417d1a2429.js" defer=""></script><script src="/aisles-online/_next/static/chunks/6266-85f0c24955b82956.js" defer=""></script><script src="/aisles-o ...

# %%
soup = BeautifulSoup(html,"lxml")
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta content="app-id=1401371704" name="apple-itunes-app"/><meta content="app-id=com.hyvee.grocery" name="google-play-app"/><meta content="hy-vee hy vee hyvee grocery food groceries stores retail supermarket super market chain iowa illinois kansas minnesota missouri nebraska south dakota wisconsin midwest floral catering bakery flowers" name="keywords"/><link href="https://172b0f0ebe158dd4e857-60490dee3451547335d9eb6f9bd3cac0.ssl.cf2.rackcdn.com/hy-vee-app-icon-web-appstore-links.png" rel="apple-touch-icon"/><link href="https://172b0f0ebe158dd4e857-60490dee3451547335d9eb6f9bd3cac0.ssl.cf2.rackcdn.com/hy-vee-app-icon-web-appstore-links.png" rel="android-touch-icon"/><link href="https://8e3463198116a37cf901-4c8f9ce7667a46d130eda30090f49466.ssl.cf2.rackcdn.com/images/favicon.ico" rel="icon"/><style type="text/css">.fresnel-container{margin:0;padding:0;}
# @media not all and (min-width:0px) and (max-width:599px){.fresnel-at-mobile{display:none!important;}}
# @media not all and (min-width:600px){.fresnel-at-desktop{display:none!important;}}
# @media not all and (max-width:599px){.fresnel-lessThan-desktop{display:none!important;}}
# @media not all and (min-width:600px){.fresnel-greaterThan-mobile{display:none!important;}}
# @media not all and (min-width:0px){.fresnel-greaterThanOrEqual-mobile{display:none!important;}}
# @media not all and (min-width:600px){.fresnel-greaterThanOrEqual-desktop{display:none!important;}}
# @media not all and (min-width:0px) and (max-width:599px){.fresnel-between-mobile-desktop{display:none!important;}}</style><meta content="width=device-width" name="viewport"/><meta charset="utf-8"/><meta content="Easily order groceries online for curbside pickup or delivery. Pickup is always free with a minimum $24.95 purchase. Aisles Online has thousands of low-price items to choose from, so you can shop your list without ever leaving the house." name="description"/><meta content="Easily order groceries online for curbside pickup or delivery. Pickup is always free with a minimum $24.95 purchase. Aisles Online has thousands of low-price items to choose from, so you can shop your list without ever leaving the house." property="og:description"/><meta content="Hy-Vee" property="og:site_name"/><link as="fetch" crossorigin="anonymous" data-testid="user-details-preload" href="/aisles-online/api/user-details" rel="preload"/><title>Hy-Vee Aisles Online Grocery Shopping</title><meta content="Hy-Vee Aisles Online Grocery Shopping" property="og:title"/><meta content="index,follow" name="robots"/><meta content="9" name="next-head-count"/><link as="style" href="/aisles-online/_next/static/css/c8567be1e24a2e0c.css" rel="preload"/><link data-n-g="" href="/aisles-online/_next/static/css/c8567be1e24a2e0c.css" rel="stylesheet"/><link as="style" href="/aisles-online/_next/static/css/6889a72415cb03a2.css" rel="preload"/><link data-n-p="" href="/aisles-online/_next/static/css/6889a72415cb03a2.css" rel="stylesheet"/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="/aisles-online/_next/static/chunks/polyfills-5cd94c89d3acac5f.js"></script><script defer="" src="/aisles-online/_next/static/chunks/webpack-05ab1068072e5bc6.js"></script><script defer="" src="/aisles-online/_next/static/chunks/framework-eeba1b405d308ec4.js"></script><script defer="" src="/aisles-online/_next/static/chunks/main-085296005cd4075e.js"></script><script defer="" src="/aisles-online/_next/static/chunks/pages/_app-7076a822db5fcf0b.js"></script><script defer="" src="/aisles-online/_next/static/chunks/418d5933-3c8b7a39282f7751.js"></script><script defer="" src="/aisles-online/_next/static/chunks/8901-bf63b8f1ebe3246f.js"></script><script defer="" src="/aisles-online/_next/static/chunks/5143-fff019b8503e53b3.js"></script><script defer="" src="/aisles-online/_next/static/chunks/4429-4bed98417d1a2429.js"></script><script defer="" src="/aisles-online/_next/static/chunks/6266-85f0c24955b82956.js"></script><script defer="" src="/aisles-online/_next/static/chunks/7306-c349acf9e5548aad.js"></script><script defer="" src="/aisles-online/_next/static/chunks/9732-a0b50c184c60e1df.js"></script><script defer="" src="/aisles-online/_next/static/chunks/4376-6c82d29ebd856100.js"></script><script defer="" src="/aisles-online/_next/static/chunks/6915-daf5fb1717f364e9.js"></script><script defer="" src="/aisles-online/_next/static/chunks/6066-92f6ec69e4a857d0.js"></script><script defer="" src="/aisles-online/_next/static/chunks/4636-5ed1328f459c31fb.js"></script><script defer="" src="/aisles-online/_next/static/chunks/8908-d45b573488dce962.js"></script><script defer="" src="/aisles-online/_next/static/chunks/6447-a74946cbe40d068f.js"></script><script defer="" src="/aisles-online/_next/static/chunks/5675-c23a6f02b9fd8af7.js"></script><script defer="" src="/aisles-online/_next/static/chunks/1899-18a3e3ca1b9227b6.js"></script><script defer="" src="/aisles-online/_next/static/chunks/1216-537c8668d11180f5.js"></script><script defer="" src="/aisles-online/_next/static/chunks/1750-c8b9a9f15016596c.js"></script><script defer="" src="/aisles-online/_next/static/chunks/3345-e463c0c1ea8d3726.js"></script><script defer="" src="/aisles-online/_next/static/chunks/9777-9fcac53cb2d07f19.js"></script><script defer="" src="/aisles-online/_next/static/chunks/2201-9bd3cbb4dc5e2d91.js"></script><script defer="" src="/aisles-online/_next/static/chunks/2605-a09d9dbceaad7e7a.js"></script><script defer="" sr ...
# /* sc-component-id: sc-global-427663078 */
# html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,menu,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,main,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;} article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section{display:block;} *[hidden]{display:none;} body{line-height:1;} menu,ol,ul{list-style:none;} blockquote,q{quotes:none;} blockquote:before,blockquote:after,q:before,q:after{content:'';content:none;} table{border-collapse:collapse;border-spacing:0;} body{color:#3F3F3F;font-family:var(--font-family);font-size:1rem;font-weight:300;line-height:1.75;} *:focus:not(.focus-visible){outline:none;} *.focus-visible{outline:none;box-shadow:0 0 0 2px #707070;}
# /* sc-component-id: sc-global-2320801092 */
# button:hover:disabled{cursor:not-allowed;} footer{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;} main{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;} strong{font-weight:500;} html,body{height:100%;min-height:100vh;} #__next{height:100%;}
# /* sc-component-id: product-card-skeleton__StyledContainer-sc-1mx81y5-0 */
# .dKvfwK{display:grid;grid-template-areas:'.' 'productDetails' 'button';grid-template-columns:auto;grid-template-rows:auto 80px 48px;min-width:215px;max-width:217px;padding:24px;-webkit-animation:cBkQmo 1s infinite ease-in-out;animation:cBkQmo 1s infinite ease-in-out;border:1px solid #F5F5F5;min-height:300px;height:auto;grid-template-areas:'. .' '. productDetails' '. button';grid-template-columns:1fr 3fr;grid-template-rows:auto 80px 48px;width:100%;min-width:100%;max-width:100%;min-height:0;height:225px;}
# /* sc-component-id: product-card-skeleton__StyledBodyContainer-sc-1mx81y5-1 */
# .kqBUZy{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;grid-area:productDetails;}
# /* sc-component-id: product-card-skeleton__StyledPrice-sc-1mx81y5-2 */
# .cdSBWD{height:20px;width:100px;margin-bottom:8px;-webkit-animation:cBkQmo 1s infinite ease-in-out;animation:cBkQmo 1s infinite ease-in-out;background-color:#F5F5F5;}
# /* sc-component-id: product-card-skeleton__StyledProductTitle-sc-1mx81y5-3 */
# .foRGyO{height:10px;min-width:130px;max-width:175px;margin-bottom:8px;-webkit-animation:cBkQmo 1s infinite ease-in-out;animation:cBkQmo 1s infinite ease-in-out;background-color:#F5F5F5;}
# /* sc-component-id: product-card-skeleton__StyledProductSubTitle-sc-1mx81y5-4 */
# .ekWtfW{height:10px;width:75px;margin-bottom:8px;-webkit-animation:cBkQmo 1s infinite ease-in-out;animation:cBkQmo 1s infinite ease-in-out;background-color:#F5F5F5;}
# /* sc-component-id: product-card-skeleton__StyledButton-sc-1mx81y5-5 */
# .dDmuUP{height:48px;-webkit-animation:cBkQmo 1s infinite ease-in-out;animation:cBkQmo 1s infinite ease-in-out;border:1px solid #F5F5F5;grid-area:button;}
# /* sc-component-id: aisles-online-header-styles__ReservationButtonHeaderContainer-sc-1kx41ue-0 */
# .ioPsnU{height:56px;} @media (min-width:1184px){.ioPsnU{height:164px;}}
# /* sc-component-id: auth-iframe__StyledIframe-sc-xqh5g2-0 */
# .jhpTU{display:none;}
# /* sc-component-id: browse-header-loading-component__StyledBreadcrumbs-sc-emtal4-0 */
# .dhcuMJ{background-color:#F5F5F5;-webkit-animation:cBkQmo 1s infinite ease-in-out;animation:cBkQmo 1s infinite ease-in-out;height:16px;width:20em;margin-top:8px;margin-bottom:8px;} @media (min-width:901px){.dhcuMJ{margin-bottom:16px;}}
# /* sc-component-id: browse-header-loading-component__StyledTitle-sc-emtal4-1 */
# .jsZRmN{background-color:#F5F5F5;-webkit-animation:cBkQmo 1s infinite ease-in-out;animation:cBkQmo 1s infinite ease-in-out;padding-bottom:16px;margin-bottom:4px;margin-left:0;height:3em;width:20em;} @media (max-width:1334px){.jsZRmN{margin:8px 0 16px 0;width:8em;}}
# /* sc-component-id: browse-header-loading-component__PageContainer-sc-emtal4-2 */
# .exNwDL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;width:100%;max-width:1331px;margin:4px auto auto auto;padding-left:8px;} @media (min-width:901px){.exNwDL{margin-top:24px;}}
# /* sc-component-id: browse-header-loading-component__StyledSectionHeader-sc-emtal4-3 */
# .dxpKKZ{background:#F5F5F5;border-bottom:solid 1px #E8E8E8;padding-left:8px;margin-bottom:4px;width:100%;} @media (min-width:901px){.dxpKKZ{padding-bottom:16px;margin-left:0;}}
# /* sc-component-id: search-products-skeleton__StyledLoadingWrapper-sc-q3pnw4-0 */
# .dPRcIX{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;width:100%;max-width:1200px;margin-top:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;} @media (min-width:901px){.dPRcIX{-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}}
# /* sc-component-id: search-filters-skeleton__StyledLoadingWrapper-sc-1sfw69w-0 */
# .kUGIpJ{margin-right:32px;width:190px;} @media (max-width:900px){.kUGIpJ{display:none;}}
# /* sc-component-id: search-filters-skeleton__StyledHyVeeFilter-sc-1sfw69w-1 */
# .eRpMfe{height:32px;width:190px;background-color:#F5F5F5;margin-bottom:16px;-webkit-animation:cBkQmo 1s infinite ease-in-out;animation:cBkQmo 1s infinite ease-in-out;}
# /* sc-component-id: search-filters-skeleton__StyledGroupHeaderFilter-sc-1sfw69w-2 */
# .gZkicO{height:40px;width:190px;background-color:#F5F5F5;margin-top:16px;-webkit-animation:cBkQmo 1s infinite ease-in-out;animation:cBkQmo 1s infinite ease-in-out;}
# /* sc-component-id: search-filters-skeleton__StyledFilterGroup-sc-1sfw69w-3 */
# .crVFhu{height:260px;width:190px;background-color:#F5F5F5;margin-bottom:2px;border:1px solid #F5F5F5;-webkit-animation:cBkQmo 1s infinite ease-in-out;animation:cBkQmo 1s infinite ease-in-out;}
# /* sc-component-id: sort-by-skeleton__StyledHyVeeFilter-sc-kmf0fv-0 */
# .ljHCxI{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100px;height:38px;border-radius:4px;margin-bottom:4px;-webkit-animation:cBkQmo 1s infinite ease-in-out;animation:cBkQmo 1s infinite ease-in-out;border:1px solid #F5F5F5;} @media (min-width:901px){.ljHCxI{width:198px;-webkit-align-self:flex-end;-ms-flex-item-align:end;align-self:flex-end;}}
# /* sc-component-id: search-page-loading__StyledLoadingPageWrapper-sc-1up2cb0-0 */
# .rJnbb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:100%;max-width:1331px;}
# /* sc-component-id: search-page-loading__StyledTopBar-sc-1up2cb0-1 */
# .fAaKyU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;max-width:1331px;margin-bottom:8px;margin-top:8px;justify-items:flex-end;}
# /* sc-component-id: search-page-loading__StyledMainContent-sc-1up2cb0-2 */
# .hPZYTX{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;width:100%;max-width:1331px;}
# /* sc-component-id: search-page-loading__StyledRow-sc-1up2cb0-4 */
# .bTwACJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}
# /* sc-component-id: search-page-loading__StyledSpacing-sc-1up2cb0-5 */
# .gtwJOH{height:12px;}
# /* sc-component-id: browse-container__PageContainer-sc-1dggiv3-0 */
# .hantMC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;width:100%;max-width:1331px;}</style><style data-styled="cBkQmo" data-styled-version="4.1.2">
# /* sc-component-id: sc-keyframes-cBkQmo */
# @-webkit-keyframes cBkQmo{0%{opacity:100%;}50%{opacity:30%;}100%{opacity:100%;}} @keyframes cBkQmo{0%{opacity:100%;}50%{opacity:30%;}100%{opacity:100%;}}</style><script async="" src="/cdn-cgi/bm/cv/669835187/api.js"></script></head><body><div id="__next"><a class="header-styles_skipNavigation__WGYOp" data-testid="skip-navigation" href="#main">Skip to Main Content</a><div class="style-constants_styledRelativeContainer__rO4Hb"><div class="style-constants_styledFixedContainer__UAhai"><div class="aisles-online-header-styles__ReservationButtonHeaderContainer-sc-1kx41ue-0 ioPsnU"><header class="aisles-online-header"><nav aria-label="Mobile Menu" class="mobile-menu-nav"><div class="mobile-header-navigation-button-container"><div class="half-menu-container"><button aria-expanded="false" aria-label="Open navigation menu" class="mobile-header-navigation-hamburger-menu-button" type="button"><svg aria-hidden="true" class="index-module_svg___KYnF" height="24px" viewbox="0 0 32 32" width="24px"><g><path d="M27 17H5a1 1 0 010-2h22a1 1 0 010 2zM27 10H5a1 1 0 010-2h22a1 1 0 010 2zM27 24H5a1 1 0 010-2h22a1 1 0 010 2z" fill="#b5b5b5"></path></g></svg></button><button class="mobile-header-navigation-search-menu-button" type="button"><svg aria-label="search" class="index-module_svg___KYnF" height="24px" role="img" viewbox="0 0 32 32" width="24px"><g><path d="M11 4a7.008 7.008 0 00-7 7 1 1 0 002 0 5.006 5.006 0 015-5 1 1 0 000-2z" fill="#b5b5b5"></path><path d="M31.707 27.226l-9.29-9.291a12.033 12.033 0 10-4.483 4.481l9.292 9.291a1 1 0 001.414 0l3.067-3.067a1 1 0 000-1.414zM2 12a10 10 0 1110 10A10.011 10.011 0 012 12zm25.933 17.586l-8.32-8.318a12.106 12.106 0 001.654-1.654l8.319 8.319z" fill="#b5b5b5"></path></g></svg></button></div><a class="aisles-online-stacked-logo-link" href="/aisles-online" title="Hy-Vee Aisles Online"><svg aria-label="Aisles Online Stacked" class="aisles-online-logo" focusable="false" role="img" viewbox="0 0 338 78" x="0" y="0"><g><path d="M35.7,55.6c0-8.8-7.2-16-16-16s-16,7.2-16,16s7.2,16,16,16c2,0,3.9-0.3,5.7-1c1.7-0.6,2.5-2.5,1.9-4.2c-0.6-1.7-2.5-2.5-4.2-1.9c-1.1,0.4-2.2,0.6-3.4,0.6c-5.3,0-9.5-4.3-9.5-9.5c0-5.3,4.3-9.5,9.5-9.5c5.3,0,9.5,4.3,9.5,9.5l0,0v13.6c0,1.8,1.4,3.2,3.2,3.2c1.8,0,3.2-1.4,3.2-3.2L35.7,55.6L35.7,55.6L35.7,55.6z" fill="#E2231A"></path><path d="M86,72.4c-1.8,0-3.2-1.4-3.2-3.2V29.9c0-1.8,1.4-3.2,3.2-3.2s3.2,1.4,3.2,3.2v39.2C89.2,70.9,87.8,72.4,86,72.4" fill="#E2231A"></path><path d="M65.7,53L65.7,53c-4.6-0.7-6.6-2.1-6.6-3.1c0-0.5,0-2.2,2.6-3.1c3-1,7.5-0.2,9.6,2.8c1,1.4,3.1,1.8,4.5,0.7c1.4-1,1.8-3,0.7-4.5c-4-5.6-11.7-6.8-16.8-5.2c-4.4,1.4-7.1,4.9-7.1,9.2c0,2.9,1.6,7.9,12.1,9.5l0,0c4.6,0.7,6.6,2.1,6.6,3.1c0,0.5,0,2.2-2.6,3.1c-3,0.9-7.5,0.1-9.6-2.8c-1-1.4-3-1.8-4.5-0.7c-1.4,1-1.8,3-0.7,4.5c2.9,4.1,7.8,5.9,12.2,5.9c1.6,0,3.2-0.2,4.5-0.7c4.5-1.4,7.1-4.9,7.1-9.2C77.8,59.6,76.3,54.6,65.7,53" fill="#E2231A"></path><path d="M142.1,53L142.1,53c-4.6-0.7-6.6-2.1-6.6-3.1c0-0.5,0-2.2,2.6-3.1c3-1,7.5-0.2,9.6,2.8c1,1.4,3.1,1.8,4.5,0.7c1.4-1,1.8-3,0.7-4.5c-4-5.6-11.7-6.8-16.8-5.2c-4.5,1.4-7.1,4.9-7.1,9.2c0,2.9,1.6,7.9,12.1,9.5l0,0c4.6,0.7,6.6,2.1,6.6,3.1c0,0.5,0,2.2-2.6,3.1c-3,1-7.5,0.1-9.6-2.8c-1-1.4-3-1.8-4.5-0.7c-1.4,1-1.8,3-0.7,4.5c2.9,4.1,7.8,5.9,12.2,5.9c1.6,0,3.2-0.2,4.5-0.7c4.5-1.4,7.1-4.9,7.1-9.2C154.2,59.6,152.6,54.6,142.1,53" fill="#E2231A"></path><path d="M109.8,72.4c-8.8,0-16-7.2-16-16s7.2-16,16-16s16,7.2,16,16c0,1.8-1.4,3.2-3.2,3.2h-15.7c-1.8,0-3.2-1.4-3.2-3.2s1.4-3.2,3.2-3.2h11.9c-1.3-3.7-4.8-6.3-9-6.3c-5.3,0-9.5,4.3-9.5,9.5c0,5.3,4.3,9.5,9.5,9.5c2.7,0,5.3-1.2,7.1-3.2c1.2-1.3,3.2-1.4,4.5-0.3c1.3,1.2,1.4,3.2,0.3,4.5C118.7,70.4,114.3,72.4,109.8,72.4" fill="#E2231A"></path><path d="M45.1,72.4c-1.8,0-3.2-1.4-3.2-3.2V43.6c0-1.8,1.4-3.2,3.2-3.2c1.8,0,3.2,1.4,3.2,3.2v25.5C48.3,70.9,46.9,72.4,45.1,72.4" fill="#E2231A"></path><path d="M48.4,34.1c0,1.8-1.5,3.3-3.3,3.3s-3.3-1.5-3.3-3.3s1.5-3.3,3.3-3.3C46.9,30.8,48.4,32.3,48.4,34.1" fill="#E2231A"></path><path d="M182.1,63.1c-1.3,1.3-2.9,2.1-4.6,2.5c-0.1,0-0.2,0.1-0.4, ...

# %%
print(example_column)
# Out:
# [<div class="search-products__StyledSearchProductCardsContainer-sc-1vuqqvj-0 dsAFBy"><div class="intersect-wrapper_wrapper__BYwpN" data-testid="wrapper"><div class="lazyload-wrapper " style="display: flex; justify-content: center; width: auto;"><article aria-posinset="1" aria-setsize="-1" class="product-card-simple__ProductWrapper-sc-1gm09hs-0 ftwOaD" data-personalized-product="false" data-placement-type="1" data-testid="product-card"><div class="styles__ContainerWithHiddenBorders-fsf453-4 styles__CardContainer-fsf453-5 gSzimD" data-testid="card-container" href="/aisles-online/p/891145/Honeycrisp-Apples" title="Honeycrisp Apples" width="215px"><div class="styles__CenterAlignSection-fsf453-0 styles__IconSection-fsf453-18 cOHyLp"></div><a aria-label="$1.57 Honeycrisp Apples 0.45 lbs click to view product details" class="styles__DrillDownSection-fsf453-2 glaVVC" href="/aisles-online/p/891145/Honeycrisp-Apples" role="link" tabindex="0"><div class="product-card-simple__StyledImageContainer-sc-1gm09hs-1 kxNpbT" data-testid="productImageContainer"><span style="box-sizing: border-box; display: inline-block; overflow: hidden; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; position: relative; max-width: 100%;"><span style="box-sizing: border-box; display: block; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; max-width: 100%;"><img alt="" aria-hidden="true" src="..." style="display: block; max-width: 100%; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px;"/></span><img alt="Honeycrisp Apples image" data-nimg="intrinsic" decoding="async" src="https://api.hy-vee.cloud/cdn-cgi/image/f=auto,w=384,q=60,dpr=1/https://fa74d61d848a20b729bb-0251b36b713060ab3e0e8321940e01ff.ssl.cf2.rackcdn.com/309ae053-8d1d-49d1-8a72-6d3e6da3544c_medium.png" srcset="https://api.hy-vee.cloud/cdn-cgi/image/f=auto,w=256,q=60,dpr=1/https://fa74d61d848a20b729bb-0251b36b713060ab3e0e8321940e01ff.ssl.cf2.rackcdn.com/309ae053-8d1d-49d1-8a72-6d3e6da3544c_medium.png 1x, https://api.hy-vee.cloud/cdn-cgi/image/f=auto,w=384,q=60,dpr=1/https://fa74d61d848a20b729bb-0251b36b713060ab3e0e8321940e01ff.ssl.cf2.rackcdn.com/309ae053-8d1d-49d1-8a72-6d3e6da3544c_medium.png 2x" style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/><noscript></noscript></span></div><div class="styles__CenterAlignSection-fsf453-0 styles__ProductInfoSection-fsf453-7 ehQApI"><div class="styles__PriceContainer-fsf453-15 hOqNxr"><p class="styles__Price-fsf453-16 hncnEy">$1.57</p><p class="styles__WeightedPrice-fsf453-17 cIvUOK">$3.49/lb</p></div><p class="typography__P-r8ufwq-6 styles__ProductTitle-fsf453-13 fTQlWQ">Honeycrisp Apples</p><span class="typography__Span-r8ufwq-7 styles__ProductSubTitle-fsf453-14 bUIIXJ">0.45 lbs</span></div></a><div class="styles__RibbonSection-fsf453-11 ePmoIP"><div class="ribbon__RibbonContainer-sc-1on1mol-2 jprrVc"><div class="ribbon__BannerRibbon-sc-1on1mol-1 kCnTxx">On Sale</div><span class="ribbon__Description-sc-1on1mol-0 kSoDDp"></span></div></div><div class="styles__CenterAlignSection-fsf453-0 styles__ButtonCenterAlignSection-fsf453-1 bscOmN"><button class="button__BaseButton-sc-5cxqrk-0 add-to-cart-button__StyledOutlineButton-sc-9jyibi-0 fWSZvQ button__StyledOutlineButton-sc-5cxqrk-3 KyYTW" role="button" type="button"><span class="button__ButtonContent-sc-5cxqrk-5 bwFrJT">Log In to
# Add to Cart</span></button><div class="styles__CenterAlignSection-fsf453-0 styles__FooterContainer-fsf453-20 jauPaj"></div></div></div></article></div></div><div class="intersect-wrapper_wrapper__BYwpN" data-testid="wrapper"><div class="lazyload-wrapper " style="display: flex; justify-content: center; width: auto;"><article aria-posinset="2" aria-setsize="-1" class="product-card-simple__ProductWrapper-sc-1gm09hs-0 ftwOaD" data-personalized-product="false" data-placement-type="1" data-testid="product-card"><div class="styles__ContainerWithHiddenBorders-fsf453-4 styles__CardContainer-fsf453-5 gSzimD" data-testid="card-container" href="/aisles-online/p/37178/Fresh-Dole-Bananas" title="Fresh Dole Bananas" width="215px"><div class="styles__CenterAlignSection-fsf453-0 styles__IconSection-fsf453-18 cOHyLp"></div><a aria-label="$0.31 Fresh Dole Bananas 0.45 lbs click to view product details" class="styles__DrillDownSection-fsf453-2 glaVVC" href="/aisles-online/p/37178/Fresh-Dole-Bananas" role="link" tabindex="0"><div class="product-card-simple__StyledImageContainer-sc-1gm09hs-1 kxNpbT" data-testid="productImageContainer"><span style="box-sizing: border-box; display: inline-block; overflow: hidden; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; position: relative; max-width: 100%;"><span style="box-sizing: border-box; display: block; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; max-width: 100%;"><img alt="" aria-hidden="true" src="..." style="display: block; max-width: 100%; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px;"/></span><img alt="Fresh Dole Bananas image" data-nimg="intrinsic" decoding="async" src="https://api.hy-vee.cloud/cdn-cgi/image/f=auto,w=384,q=60,dpr=1/https://0bb8856ba8259ec33e3d-a40599a114f3a4c6d0979c3ffe0b2bf5.ssl.cf2.rackcdn.com/0000000040110_CL_hyvee4_default_medium.jpeg" srcset="https://api.hy-vee.cloud/cdn-cgi/image/f=auto,w=256,q=60,dpr=1/https://0bb8856ba8259ec33e3d-a40599a114f3a4c6d0979c3ffe0b2bf5.ssl.cf2.rackcdn.com/0000000040110_CL_hyvee4_default_medium.jpeg 1x, https://api.hy-vee.cloud/cdn-cgi/image/f=auto,w=384,q=60,dpr=1/https://0bb8856ba8259ec33e3d-a40599a114f3a4c6d0979c3ffe0b2bf5.ssl.cf2.rackcdn.com/0000000040110_CL_hyvee4_default_medium.jpeg 2x" style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/><noscript></noscript></span></div><div class="styles__CenterAlignSection-fsf453-0 styles__ProductInfoSection-fsf453-7 ehQApI"><div class="styles__PriceContainer-fsf453-15 hOqNxr"><p class="styles__Price-fsf453-16 hncnEy">$0.31</p><p class="styles__WeightedPrice-fsf453-17 cIvUOK">$0.69/lb</p></div><p class="typography__P-r8ufwq-6 styles__ProductTitle-fsf453-13 fTQlWQ">Fresh Dole Bananas</p><span class="typography__Span-r8ufwq-7 styles__ProductSubTitle-fsf453-14 bUIIXJ">0.45 lbs</span></div></a><div class="styles__RibbonSection-fsf453-11 ePmoIP"></div><div class="styles__CenterAlignSection-fsf453-0 styles__ButtonCenterAlignSection-fsf453-1 bscOmN"><button class="button__BaseButton-sc-5cxqrk-0 add-to-cart-button__StyledOutlineButton-sc-9jyibi-0 fWSZvQ button__StyledOutlineButton-sc-5cxqrk-3 KyYTW" role="button" type="button"><span class="button__ButtonContent-sc-5cxqrk-5 bwFrJT">Log In to
# Add to Cart</span></button><div class="styles__CenterAlignSection-fsf453-0 styles__FooterContainer-fsf453-20 jauPaj"></div></div></div></article></div></div><div class="intersect-wrapper_wrapper__BYwpN" data-testid="wrapper"><div class="lazyload-wrapper " style="display: flex; justify-content: center; width: auto;"><article aria-posinset="3" aria-setsize="-1" class="product-card-simple__ProductWrapper-sc-1gm09hs-0 ftwOaD" data-personalized-product="false" data-placement-type="4" data-testid="product-card"><div class="styles__ContainerWithHiddenBorders-fsf453-4 styles__CardContainer-fsf453-5 gSzimD" data-testid="card-container" href="/aisles-online/p/267885/Thats-Smart-Bananas" title="That's Smart! Bananas" width="215px"><div class="styles__CenterAlignSection-fsf453-0 styles__IconSection-fsf453-18 cOHyLp"></div><a aria-label="$0.20 That's Smart! Bananas 0.45 lbs click to view product details" class="styles__DrillDownSection-fsf453-2 glaVVC" href="/aisles-online/p/267885/Thats-Smart-Bananas" role="link" tabindex="0"><div class="product-card-simple__StyledImageContainer-sc-1gm09hs-1 kxNpbT" data-testid="productImageContainer"><span style="box-sizing: border-box; display: inline-block; overflow: hidden; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; position: relative; max-width: 100%;"><span style="box-sizing: border-box; display: block; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; max-width: 100%;"><img alt="" aria-hidden="true" src="..." style="display: block; max-width: 100%; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px;"/></span><img alt="That's Smart! Bananas image" data-nimg="intrinsic" decoding="async" src="https://api.hy-vee.cloud/cdn-cgi/image/f=auto,w=384,q=60,dpr=1/https://8e9d5b8b8dcb9208ef3f-01db2a53ae0368d03387780ee86ead55.ssl.cf2.rackcdn.com/0000000042370_CF_hyvee1_default_medium.jpeg" srcset="https://api.hy-vee.cloud/cdn-cgi/image/f=auto,w=256,q=60,dpr=1/https://8e9d5b8b8dcb9208ef3f-01db2a53ae0368d03387780ee86ead55.ssl.cf2.rackcdn.com/0000000042370_CF_hyvee1_default_medium.jpeg 1x, https://api.hy-vee.cloud/cdn-cgi/image/f=auto,w=384,q=60,dpr=1/https://8e9d5b8b8dcb9208ef3f-01db2a53ae0368d03387780ee86ead55.ssl.cf2.rackcdn.com/0000000042370_CF_hyvee1_default_medium.jpeg 2x" style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/><noscript></noscript></span></div><div class="styles__CenterAlignSection-fsf453-0 styles__ProductInfoSection-fsf453-7 ehQApI"><div class="styles__PriceContainer-fsf453-15 hOqNxr"><p class="styles__Price-fsf453-16 hncnEy">$0.20</p><p class="styles__WeightedPrice-fsf453-17 cIvUOK">$0.44/lb</p></div><p class="typography__P-r8ufwq-6 styles__ProductTitle-fsf453-13 fTQlWQ">That's Smart! Bananas</p><span class="typography__Span-r8ufwq-7 styles__ProductSubTitle-fsf453-14 bUIIXJ">0.45 lbs</span></div></a><div class="styles__RibbonSection-fsf453-11 ePmoIP"><div class="ribbon__RibbonContainer-sc-1on1mol-2 jprrVc"><div class="ribbon__BannerRibbon-sc-1on1mol-1 kCnTxx">On Sale</div><span class="ribbon__Description-sc-1on1mol-0 kSoDDp"></span></div></div><div class="styles__CenterAlignSection-fsf453-0 styles__ButtonCenterAlignSection-fsf453-1 bscOmN"><button class="button__BaseButton-sc-5cxqrk-0 add-to-cart-button__StyledOutlineButton-sc-9jyibi-0 fWSZvQ button__StyledOutlineButton-sc-5cxqrk-3 KyYTW" role="button" type="button"><span class="button__ButtonContent-sc-5cxqrk-5 bwFrJT">Log In to
# Add to Cart</span></button><div class="styles__CenterAlignSection-fsf453-0 styles__FooterContainer-fsf453-20 jauPaj"></div></div></div></article></div></div><div class="intersect-wrapper_wrapper__BYwpN" data-testid="wrapper"><div class="lazyload-wrapper " style="display: flex; justify-content: center; width: auto;"><article aria-posinset="4" aria-setsize="-1" class="product-card-simple__ProductWrapper-sc-1gm09hs-0 ftwOaD" data-personalized-product="false" data-placement-type="1" data-testid="product-card"><div class="styles__ContainerWithHiddenBorders-fsf453-4 styles__CardContainer-fsf453-5 gSzimD" data-testid="card-container" href="/aisles-online/p/371584/Wonderful-Halos-Mandarin-Oranges" title="Wonderful Halos Mandarin Oranges" width="215px"><div class="styles__CenterAlignSection-fsf453-0 styles__IconSection-fsf453-18 cOHyLp"></div><a aria-label="$7.99 Wonderful Halos Mandarin Oranges 3 lb  click to view product details" class="styles__DrillDownSection-fsf453-2 glaVVC" href="/aisles-online/p/371584/Wonderful-Halos-Mandarin-Oranges" role="link" tabindex="0"><div class="product-card-simple__StyledImageContainer-sc-1gm09hs-1 kxNpbT" data-testid="productImageContainer"><span style="box-sizing: border-box; display: inline-block; overflow: hidden; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; position: relative; max-width: 100%;"><span style="box-sizing: border-box; display: block; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; max-width: 100%;"><img alt="" aria-hidden="true" src="..." style="display: block; max-width: 100%; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px;"/></span><img alt="Wonderful Halos Mandarin Oranges image" data-nimg="intrinsic" decoding="async" src="https://api.hy-vee.cloud/cdn-cgi/image/f=auto,w=384,q=60,dpr=1/https://b88999e18c89e80431a4-abc09c86eb4dd7b78c0b34703b49a2cf.ssl.cf2.rackcdn.com/0072240133810_A1A3_ItemMaster_default_medium.jpeg" srcset="https://api.hy-vee.cloud/cdn-cgi/image/f=auto,w=256,q=60,dpr=1/https://b88999e18c89e80431a4-abc09c86eb4dd7b78c0b34703b49a2cf.ssl.cf2.rackcdn.com/0072240133810_A1A3_ItemMaster_default_medium.jpeg 1x, https://api.hy-vee.cloud/cdn-cgi/image/f=auto,w=384,q=60,dpr=1/https://b88999e18c89e80431a4-abc09c86eb4dd7b78c0b34703b49a2cf.ssl.cf2.rackcdn.com/0072240133810_A1A3_ItemMaster_default_medium.jpeg 2x" style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/><noscript></noscript></span></div><div class="styles__CenterAlignSection-fsf453-0 styles__ProductInfoSection-fsf453-7 ehQApI"><div class="styles__PriceContainer-fsf453-15 hOqNxr"><p class="styles__Price-fsf453-16 hncnEy">$7.99</p></div><p class="typography__P-r8ufwq-6 styles__ProductTitle-fsf453-13 fTQlWQ">Wonderful Halos Mandarin Oranges</p><span class="typography__Span-r8ufwq-7 styles__ProductSubTitle-fsf453-14 bUIIXJ">3 lb </span></div></a><div class="styles__RibbonSection-fsf453-11 ePmoIP"></div><div class="styles__CenterAlignSection-fsf453-0 styles__ButtonCenterAlignSection-fsf453-1 bscOmN"><button class="button__BaseButton-sc-5cxqrk-0 add-to-cart-button__StyledOutlineButton-sc-9jyibi-0 fWSZvQ button__StyledOutlineButton-sc-5cxqrk-3 KyYTW" role="button" type="button"><span class="button__ButtonContent-sc-5cxqrk-5 bwFrJT">Log In to
# Add to Cart</span></button><div class="styles__CenterAlignSection-fsf453-0 styles__FooterContainer-fsf453-20 jauPaj"></div></div></div></article></div></div><div class="intersect-wrapper_wrapper__BYwpN" data-testid="wrapper"><div class="lazyload-wrapper " style="display: flex; justify-content: center; width: auto;"><article aria-posinset="5" aria-setsize="-1" class="product-card-simple__ProductWrapper-sc-1gm09hs-0 ftwOaD" data-personalized-product="false" data-placement-type="1" data-testid="product-card"><div class="styles__ContainerWithHiddenBorders-fsf453-4 styles__CardContainer-fsf453-5 gSzimD" data-testid="card-container" href="/aisles-online/p/8669/Gala-Apples" title="Gala Apples" width="215px"><div class="styles__CenterAlignSection-fsf453-0 styles__IconSection-fsf453-18 cOHyLp"></div><a aria-label="$0.90 Gala Apples 0.45 lbs click to view product details" class="styles__DrillDownSection-fsf453-2 glaVVC" href="/aisles-online/p/8669/Gala-Apples" role="link" tabindex="0"><div class="product-card-simple__StyledImageContainer-sc-1gm09hs-1 kxNpbT" data-testid="productImageContainer"><span style="box-sizing: border-box; display: inline-block; overflow: hidden; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; position: relative; max-width: 100%;"><span style="box-sizing: border-box; display: block; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; max-width: 100%;"><img alt="" aria-hidden="true" src="..." style="display: block; max-width: 100%; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px;"/></span><img alt="Gala Apples image" data-nimg="intrinsic" decoding="async" src="https://api.hy-vee.cloud/cdn-cgi/image/f=auto,w=384,q=60,dpr=1/https://0bb8856ba8259ec33e3d-a40599a114f3a4c6d0979c3ffe0b2bf5.ssl.cf2.rackcdn.com/0000000041330_CL_hyvee_default_medium.jpeg" srcset="https://api.hy-vee.cloud/cdn-cgi/image/f=auto,w=256,q=60,dpr=1/https://0bb8856ba8259ec33e3d-a40599a114f3a4c6d0979c3ffe0b2bf5.ssl.cf2.rackcdn.com/0000000041330_CL_hyvee_default_medium.jpeg 1x, https://api.hy-vee.cloud/cdn-cgi/image/f=auto,w=384,q=60,dpr=1/https://0bb8856ba8259ec33e3d-a40599a114f3a4c6d0979c3ffe0b2bf5.ssl.cf2.rackcdn.com/0000000041330_CL_hyvee_default_medium.jpeg 2x" style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/><noscript></noscript></span></div><div class="styles__CenterAlignSection-fsf453-0 styles__ProductInfoSection-fsf453-7 ehQApI"><div class="styles__PriceContainer-fsf453-15 hOqNxr"><p class="styles__Price-fsf453-16 hncnEy">$0.90</p><p class="styles__WeightedPrice-fsf453-17 cIvUOK">$1.99/lb</p></div><p class="typography__P-r8ufwq-6 styles__ProductTitle-fsf453-13 fTQlWQ">Gala Apples</p><span class="typography__Span-r8ufwq-7 styles__ProductSubTitle-fsf453-14 bUIIXJ">0.45 lbs</span></div></a><div class="styles__RibbonSection-fsf453-11 ePmoIP"></div><div class="styles__CenterAlignSection-fsf453-0 styles__ButtonCenterAlignSection-fsf453-1 bscOmN"><button class="button__BaseButton-sc-5cxqrk-0 add-to-cart-button__StyledOutlineButton-sc-9jyibi-0 fWSZvQ button__StyledOutlineButton-sc-5cxqrk-3 KyYTW" role="button" type="button"><span class="button__ButtonContent-sc-5cxqrk-5 bwFrJT">Log In to
# Add to Cart</span></button><div class="styles__CenterAlignSection-fsf453-0 styles__FooterContainer-fsf453-20 jauPaj"></div></div></div></article></div></div><div class="intersect-wrapper_wrapper__BYwpN" data-testid="wrapper"><div class="lazyload-wrapper " style="display: flex; justify-content: center; width: auto;"><article aria-posinset="6" aria-setsize="-1" class="product-card-simple__ProductWrapper-sc-1gm09hs-0 ftwOaD" data-personalized-product="false" data-placement-type="3" data-testid="product-card"><div class="styles__ContainerWithHiddenBorders-fsf453-4 styles__CardContainer-fsf453-5 gSzimD" data-testid="card-container" href="/aisles-online/p/37191/Limes" title="Limes" width="215px"><div class="styles__CenterAlignSection-fsf453-0 styles__IconSection-fsf453-18 cOHyLp"></div><a aria-label="$1.39 Limes 1 ea  click to view product details" class="styles__DrillDownSection-fsf453-2 glaVVC" href="/aisles-online/p/37191/Limes" role="link" tabindex="0"><div class="product-card-simple__StyledImageContainer-sc-1gm09hs-1 kxNpbT" data-testid="productImageContainer"><span style="box-sizing: border-box; display: inline-block; overflow: hidden; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; position: relative; max-width: 100%;"><span style="box-sizing: border-box; display: block; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; max-width: 100%;"><img alt="" aria-hidden="true" src="..." style="display: block; max-width: 100%; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px;"/></span><img alt="Limes image" data-nimg="intrinsic" decoding="async" src="https://api.hy-vee.cloud/cdn-cgi/image/f=auto,w=384,q=60,dpr=1/https://0bb8856ba8259ec33e3d-a40599a114f3a4c6d0979c3ffe0b2bf5.ssl.cf2.rackcdn.com/0000000040480_CL_hyvee_default_medium.jpeg" srcset="https://api.hy-vee.cloud/cdn-cgi/image/f=auto,w=256,q=60,dpr=1/https://0bb8856ba8259ec33e3d-a40599a114f3a4c6d0979c3ffe0b2bf5.ssl.cf2.rackcdn.com/0000000040480_CL_hyvee_default_medium.jpeg 1x, https://api.hy-vee.cloud/cdn-cgi/image/f=auto,w=384,q=60,dpr=1/https://0bb8856ba8259ec33e3d-a40599a114f3a4c6d0979c3ffe0b2bf5.ssl.cf2.rackcdn.com/0000000040480_CL_hyvee_default_medium.jpeg 2x" style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/><noscript></noscript></span></div><div class="styles__CenterAlignSection-fsf453-0 styles__ProductInfoSection-fsf453-7 ehQApI"><div class="styles__PriceContainer-fsf453-15 hOqNxr"><p class="styles__Price-fsf453-16 hncnEy">$1.39</p></div><p class="typography__P-r8ufwq-6 styles__ProductTitle-fsf453-13 fTQlWQ">Limes</p><span class="typography__Span-r8ufwq-7 styles__ProductSubTitle-fsf453-14 bUIIXJ">1 ea </span></div></a><div class="styles__RibbonSection-fsf453-11 ePmoIP"><div class="ribbon__RibbonContainer-sc-1on1mol-2 jprrVc"><div class="ribbon__BannerRibbon-sc-1on1mol-1 kCnTxx">On Sale</div><span class="ribbon__Description-sc-1on1mol-0 kSoDDp"></span></div></div><div class="styles__CenterAlignSection-fsf453-0 styles__ButtonCenterAlignSection-fsf453-1 bscOmN"><button class="button__BaseButton-sc-5cxqrk-0 add-to-cart-button__StyledOutlineButton-sc-9jyibi-0 fWSZvQ button__StyledOutlineButton-sc-5cxqrk-3 KyYTW" role="button" type="button"><span class="button__ButtonContent-sc-5cxqrk-5 bwFrJT">Log In to
# Add to Cart</span></button><div class="styles__CenterAlignSection-fsf453-0 styles__FooterContainer-fsf453-20 jauPaj"></div></div></div></article></div></div><div class="intersect-wrapper_wrapper__BYwpN" data-testid="wrapper"><div class="lazyload-wrapper " style="display: flex; justify-content: center; width: auto;"><article aria-setsize="-1" class="product-card-skeleton__StyledContainer-sc-1mx81y5-0 jVkydB" data-testid="productCardSkeleton"><div class="product-card-skeleton__StyledBodyContainer-sc-1mx81y5-1 kqBUZy"><div class="product-card-skeleton__StyledPrice-sc-1mx81y5-2 cdSBWD"></div><div class="product-card-skeleton__StyledProductTitle-sc-1mx81y5-3 foRGyO"></div><div class="product-card-skeleton__StyledProductSubTitle-sc-1mx81y5-4 ekWtfW"></div></div><div class="product-card-skeleton__StyledButton-sc-1mx81y5-5 dDmuUP"></div></article></div></div><div class="intersect-wrapper_wrapper__BYwpN" data-testid="wrapper"><div class="lazyload-wrapper " style="display: flex; justify-content: center; width: auto;"><article aria-setsize="-1" class="product-card-skeleton__StyledContainer-sc-1mx81y5-0 jVkydB" data-testid="productCardSkeleton"><div class="product-card-skeleton__StyledBodyContainer-sc-1mx81y5-1 kqBUZy"><div class="product-card-skeleton__StyledPrice-sc-1mx81y5-2 cdSBWD"></div><div class="product-card-skeleton__StyledProductTitle-sc-1mx81y5-3 foRGyO"></div><div class="product-card-skeleton__StyledProductSubTitle-sc-1mx81y5-4 ekWtfW"></div></div><div class="product-card-skeleton__StyledButton-sc-1mx81y5-5 dDmuUP"></div></article></div></div><div class="intersect-wrapper_wrapper__BYwpN" data-testid="wrapper"><div class="lazyload-wrapper " style="display: flex; justify-content: center; width: auto;"><article aria-setsize="-1" class="product-card-skeleton__StyledContainer-sc-1mx81y5-0 jVkydB" data-testid="productCardSkeleton"><div class="product-card-skeleton__StyledBodyContainer-sc-1mx81y5-1 kqBUZy"><div class="product-card-skeleton__StyledPrice-sc-1mx81y5-2 cdSBWD"></div><div class="product-card-skeleton__StyledProductTitle-sc-1mx81y5-3 foRGyO"></div><div class="product-card-skeleton__StyledProductSubTitle-sc-1mx81y5-4 ekWtfW"></div></div><div class="product-card-skeleton__StyledButton-sc-1mx81y5-5 dDmuUP"></div></article></div></div><div class="intersect-wrapper_wrapper__BYwpN" data-testid="wrapper"><div class="lazyload-wrapper " style="display: flex; justify-content: center; width: auto;"><article aria-setsize="-1" class="product-card-skeleton__StyledContainer-sc-1mx81y5-0 jVkydB" data-testid="productCardSkeleton"><div class="product-card-skeleton__StyledBodyContainer-sc-1mx81y5-1 kqBUZy"><div class="product-card-skeleton__StyledPrice-sc-1mx81y5-2 cdSBWD"></div><div class="product-card-skeleton__StyledProductTitle-sc-1mx81y5-3 foRGyO"></div><div class="product-card-skeleton__StyledProductSubTitle-sc-1mx81y5-4 ekWtfW"></div></div><div class="product-card-skeleton__StyledButton-sc-1mx81y5-5 dDmuUP"></div></article></div></div><div class="intersect-wrapper_wrapper__BYwpN" data-testid="wrapper"><div class="lazyload-wrapper " style="display: flex; justify-content: center; width: auto;"><article aria-setsize="-1" class="product-card-skeleton__StyledContainer-sc-1mx81y5-0 jVkydB" data-testid="productCardSkeleton"><div class="product-card-skeleton__StyledBodyContainer-sc-1mx81y5-1 kqBUZy"><div class="product-card-skeleton__StyledPrice-sc-1mx81y5-2 cdSBWD"></div><div class="product-card-skeleton__StyledProductTitle-sc-1mx81y5-3 foRGyO"></div><div class="product-card-skeleton__StyledProductSubTitle-sc-1mx81y5-4 ekWtfW"></div></div><div class="product-card-skeleton__StyledButton-sc-1mx81y5-5 dDmuUP"></div></article></div></div><div class="intersect-wrapper_wrapper__BYwpN" data-testid="wrapper"><div class="lazyload-wrapper " style="display: flex; justify-content: center; width: auto;"><article aria-setsize="-1" class="product-card-skeleton__StyledContainer-sc-1mx81y5-0 jVkydB" data-testid="productCardSkeleton"><div class="product-card- ...

# %%
for i in elements:
  print(i.text)
  print("------------")

# %%
example_list = []

for i in elements:
 example_list.append(i.text)

# %%
example_list
# Out:
# ["$1.57\n$3.49/lb\nHoneycrisp Apples\n0.45 lbs\nOn Sale\nLog In to\nAdd to Cart\n$0.31\n$0.69/lb\nFresh Dole Bananas\n0.45 lbs\nLog In to\nAdd to Cart\n$0.20\n$0.44/lb\nThat's Smart! Bananas\n0.45 lbs\nOn Sale\nLog In to\nAdd to Cart\n$7.99\nWonderful Halos Mandarin Oranges\n3 lb\nLog In to\nAdd to Cart\n$0.90\n$1.99/lb\nGala Apples\n0.45 lbs\nLog In to\nAdd to Cart\n$1.39\nLimes\n1 ea\nOn Sale\nLog In to\nAdd to Cart"]

# %%
# save the information into a CSV file
df = pd.DataFrame(example_list)
#df.to_csv("all_pages.csv")

# %%
df.head()
# Out:
#                                                    0
# 0  $1.57\n$3.49/lb\nHoneycrisp Apples\n0.45 lbs\n...

# %%
#Implicit wait 

wd.implicitly_wait(10) # seconds #this is for websites that have to load



wd.get("https://shop.iowafood.coop/product-search?IDSubcat=164")



myDynamicElement = wd.find_elements(By.XPATH, '/html/body/main/div[1]/div[2]')

#we were doing by class name, this is sorting through xpath

print(wd.page_source)
# Out:
# <html lang="en"><head>
# 	<meta charset="utf-8">
# 	<meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
# 	<meta name="robots" content="noindex">
# 	<meta name="csrf-token" content="Z5Sbw9ww-fQAl6k-MCZg3vSXrhlPRM6iq4oI">
#
# 	<title>IFC product search</title>
#
#
# 	<link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css" integrity="sha384-JcKb8q3iqJ61gNV9KGb8thSsNjpSL0n8PARn9HuZOnIxN0hoP+VmmDGMN5t9UJ0Z" crossorigin="anonymous">
#
# 	<link rel="stylesheet" href="/Static/main-14.css">
#
#
# 	<script src="https://code.jquery.com/jquery-3.5.1.min.js" integrity="sha256-9/aliU8dGd2tb6OSsuzixeV4y/faTqgFtohetphbbj0=" crossorigin="anonymous"></script>
#
# 	<script async="" src="https://cdn.jsdelivr.net/npm/popper.js@1.16.1/dist/umd/popper.min.js" integrity="sha384-9/reFTGAW83EW2RDu2S0VKaIzap3H66lZH81PoYlFhbGU+6BZp6G7niu735Sk7lN" crossorigin="anonymous"></script>
#
# 	<script async="" src="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/js/bootstrap.min.js" integrity="sha384-B4gt1jrGC7Jh4AgTPSdUtOBvfO8shuf57BaghqFfPlYxofvL8/KUEfYiJOMMV+rV" crossorigin="anonymous"></script>
#
# 	<script src="https://cdn.jsdelivr.net/npm/bs-custom-file-input@1.3.4/dist/bs-custom-file-input.min.js" integrity="sha256-e0DUqNhsFAzOlhrWXnMOQwRoqrCRlofpWgyhnrIIaPo=" crossorigin="anonymous"></script>
#
# 	<script>
# 		$(document).ready(function () {
# 			$('[data-toggle="tooltip"]').tooltip();
#
# 			bsCustomFileInput.init();
# 		});
# 	</script>
#
#
# 	<script src="/Static/main-6.js"></script>
#
# 	<script async="" src="https://www.googletagmanager.com/gtag/js?id=G-QKKRX9EPNS"></script>
# 	<script>
# 		window.dataLayer = window.dataLayer || [];
# 		function gtag(){dataLayer.push(arguments);}
# 		gtag('js', new Date());
#
# 		gtag('config', 'G-QKKRX9EPNS');
# 	</script>
# </head>
#
# <body>
#
#
# 	<noscript>
# 		<div class="Flash alert alert-warning mb-0 pt-1 pb-2" role="alert">
# 			This site requires JavaScript! Learn
# 			<a href="https://www.computerhope.com/issues/ch000891.htm"
# 				class="alert-link">how to enable it</a> in your browser.
# 		</div>
# 	</noscript>
#
# 	<div id="WarnIE" class="Flash alert alert-warning mb-0 pt-1 pb-2" role="alert">
# 		<div>
# 			Sorry, this site will not work properly with
# 			<a href="https://www.engadget.com/2019-02-08-microsoft-internet-explorer-technical-debt.html">Internet Explorer</a>!
# 			Please upgrade to a modern, secure browser:
# 		</div>
# 		<ul class="mb-0">
# 			<li>
# 				Google <a href="https://www.google.com/chrome/">Chrome</a>
# 			</li>
# 			<li>
# 				Mozilla <a href="https://www.mozilla.org/en-US/firefox/new/">Firefox</a>
# 			</li>
# 			<li>
# 				Microsoft <a href="https://www.microsoft.com/en-us/edge">Edge</a>
# 			</li>
# 		</ul>
# 	</div>
#
#
#
# 	<header class="d-print-none d-flex align-items-center">
# 		<div id="ColLogo">
# 			<a href="https://iowafood.coop/">
# 				<img class="d-none d-md-inline mr-1" src="/Static/logo-carrot.svg" alt="" height="30" style="position: relative; top: -0.04rem;">
# 			</a>
# 			<a href="https://iowafood.coop/">
# 				<img alt="" src="/Static/logo-text.svg" height="30">
# 			</a>
# 		</div>
#
#
# 		<div id="ColDates" class="flex-grow-1 text-center">
# 			<div class="d-none d-md-block">
# 				Cart closes Jun 26, 2022 11:59 PM
# 			</div>
#
# 			<div class="d-none d-md-block">
# 				<a href="https://iowafood.coop/locationshours" target="_blank">
# 					Order Pickup Details
# 				</a>
# 			</div>
#
# 		</div>
#
# 		<div id="LblBtnLogin" class="d-none d-md-block text-right mr-2">
# 			<span style="float:left;">Interested in shopping with us? </span>
# 			<a href="/member-registration">Start free trial!</a>
# 			<br>
# 			<span style="float:left; margin-right:10px;">Want to become a producer? </span>
# 			<a href="mailto:info@iowafood.coop">Email info@iowafood.coop</a>
# 		</div>
#
# 		<div id="ColLogin">
# 			<div class="text-right">
# 				<button type="button" class="btn" data-toggle="modal" data-target="#DlgLogin">Login</button>
# 			</div>
# 		</div>
# 	</header>
#
#
# 	<nav class="navbar navbar-expand-md navbar-dark">
# 		<button class="navbar-toggler" type="button" data-target="#Nav" data-toggle="collapse">
# 			<span class="navbar-toggler-icon"></span>
# 		</button>
#
# 		<div id="Nav" class="collapse navbar-collapse">
# 			<ul class="navbar-nav">
#
# 				<li class="nav-item ">
# 					<a href="/" class="nav-link double">
# 						Market
# 						<span class="d-none d-md-inline"><br></span>
# 						Home
# 					</a>
# 				</li>
# 				<li class="nav-item active">
# 					<a href="/product-search" class="nav-link double">
# 						Product
# 						<span class="d-none d-md-inline"><br></span>
# 						Search
# 					</a>
# 				</li>
#
# 			</ul>
# 		</div>
#
# 		<div id="TitleMob" class="d-md-none navbar-brand">
#
# 			Product Search
#
#
#
#
#
#
#
#
# 		</div>
# 	</nav>
#
#
#
#
# 	<div id="Flashes">
# 	</div>
#
#
# 	<div id="DlgLogin" class="modal" tabindex="-1" role="dialog">
# 		<div class="modal-dialog modal-dialog-centered">
# 			<div class="modal-content">
# 				<form action="/login" method="POST" onsubmit="Disab_Form()">
# 					<input type="hidden" name="_csrf" value="Z5Sbw9ww-fQAl6k-MCZg3vSXrhlPRM6iq4oI">
#
# 					<div class="modal-body">
# 						<div class="form-group">
# 							<label for="NameLogin">Username</label>
# 							<input id="NameLogin" name="NameLogin" type="text" required="" minlength="1" class="form-control">
# 						</div>
#
# 						<div class="form-group">
# 							<label for="Pass">Password</label>
# 							<input id="Pass" name="Pass" type="password" required="" minlength="1" class="form-control">
# 						</div>
# 					</div>
#
# 					<div class="modal-footer">
# 						<a href="/request-password-reset">
# 							Forgot your password?
# 						</a>
# 						<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgLogin">
# 							Cancel
# 						</button>
# 						<button type="submit" class="btn btn-primary">
# 							Login
# 						</button>
# 					</div>
# 				</form>
# 			</div>
# 		</div>
# 	</div>
#
#
#
#
# 	<main>
# 		<style>
# 	body {
# 		/*background: linear-gradient(120deg, hsla(66, 30%, 80%, 0.5),
# 			hsla(66, 30%, 80%, 0) 70.71%);*/
# 	}
# </style>
#
# <div class="container py-4">
# 	<form class="form-inline px-1 mb-2" action="/product-search" method="POST" onsubmit="Disab_Form()">
#
# 		<input type="hidden" name="_csrf" value="Z5Sbw9ww-fQAl6k-MCZg3vSXrhlPRM6iq4oI">
#
# 		<input id="Terms" name="Terms" type="text" value="" autofocus="" class="form-control flex-grow-1 mr-sm-2">
#
# 		<div class="d-flex">
# 			<button type="submit" class="btn btn-primary mt-2 mt-sm-0">
# 				<img src="/Static/search.svg" alt="" width="20" height="20" class="IconBtn" style="position: relative; top: -2px">
# 				Search
# 			</button>
#
# 		</div>
# 	</form>
#
# 	<div class="d-sm-flex flex-row px-1 my-3">
# 		<div class="lead">
# 			Subcategory:
# 			<strong>Kale</strong>
# 		</div>
# 		<p class="lead ml-auto mb-0">
# 			12 matches found
# 		</p>
# 	</div>
#
#
# <div class="row row-cols-1 row-cols-sm-2 row-cols-lg-3 no-gutters">
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/14383">
# 						Red Kale
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/238">
# 						Lee's Greens, LLC
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct14383" data-toggle="modal">
#
# 				<hr class="mx-0 mt-0 mb-2">
# 				<div class="Descrip">Fresh cut red kale half lb bags, great for fresh eating.</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct14383" data-toggle="modal">
#
# 				<hr class="mx-0 mt-0 mb-2">
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>half pound bag, Red russian kale</div>
# 						<div>$5.75</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/7986">
# 						Blue Curled Scotch Kale
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/299">
# 						Simon's Plant Collaboration
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct7986" data-toggle="modal">
#
# 				<div style="background-image: url('/StoreImg/A5B5MWA9NNHX.jpg');" class="Img rounded rounded-lg">
# 				</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct7986" data-toggle="modal">
#
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>bag</div>
# 						<div>$3.50</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/12294">
# 						Green Kale
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/228">
# 						Joyful Greens
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct12294" data-toggle="modal">
#
# 				<div style="background-image: url('/StoreImg/SBYK51EW02NZ.jpg');" class="Img rounded rounded-lg">
# 				</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct12294" data-toggle="modal">
#
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>bunch</div>
# 						<div>$2.50</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/13846">
# 						Dinosaur Kale
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/228">
# 						Joyful Greens
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct13846" data-toggle="modal">
#
# 				<div style="background-image: url('/StoreImg/ZC0PNB1ZQ35E.jpg');" class="Img rounded rounded-lg">
# 				</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct13846" data-toggle="modal">
#
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>bunch</div>
# 						<div>$3.00</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/8521">
# 						Curly Green Kale New crop
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/287">
# 						Red Barn Produce
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct8521" data-toggle="modal">
#
# 				<div style="background-image: url('/StoreImg/43V34MPLXXT0.jpg');" class="Img rounded rounded-lg">
# 				</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct8521" data-toggle="modal">
#
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>bag</div>
# 						<div>$3.25</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/6483">
# 						Red Russian Kale - Baby Leaf
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/299">
# 						Simon's Plant Collaboration
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct6483" data-toggle="modal">
#
# 				<div style="background-image: url('/StoreImg/0DMQG6XRR62S.jpg');" class="Img rounded rounded-lg">
# 				</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct6483" data-toggle="modal">
#
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>bag</div>
# 						<div>$4.00</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/6548">
# 						Kale: Dinosaur
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/137">
# 						Eating Well Farm
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct6548" data-toggle="modal">
#
# 				<div style="background-image: url('/StoreImg/SG2QMPER4WTH.jpg');" class="Img rounded rounded-lg">
# 				</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct6548" data-toggle="modal">
#
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>bag</div>
# 						<div>$3.00</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/6550">
# 						Kale: Scarlet
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/137">
# 						Eating Well Farm
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct6550" data-toggle="modal">
#
# 				<div style="background-image: url('/StoreImg/F6PVV08GJ62Q.jpg');" class="Img rounded rounded-lg">
# 				</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct6550" data-toggle="modal">
#
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>bag</div>
# 						<div>$3.00</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/8004">
# 						Kale: Blue Curled Scotch
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/137">
# 						Eating Well Farm
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct8004" data-toggle="modal">
#
# 				<div style="background-image: url('/StoreImg/QHJ3WAL436XJ.jpg');" class="Img rounded rounded-lg">
# 				</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct8004" data-toggle="modal">
#
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>bag</div>
# 						<div>$3.00</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			CornerBtmLeft3 ">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/8434">
# 						AG Blue Dwarf Curly Kale
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/176">
# 						Early Morning Harvest
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct8434" data-toggle="modal">
#
# 				<div style="background-image: url('/StoreImg/A4SYZ3KGKNT2.jpg');" class="Img rounded rounded-lg">
# 				</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct8434" data-toggle="modal">
#
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>bag</div>
# 						<div>$3.00</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			CornerBtmLeft2 ">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/8627">
# 						AG Tascano Kale
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/176">
# 						Early Morning Harvest
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct8627" data-toggle="modal">
#
# 				<div style="background-image: url('/StoreImg/JPXK43Z9MQAK.jpg');" class="Img rounded rounded-lg">
# 				</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct8627" data-toggle="modal">
#
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>bunch</div>
# 						<div>$3.00</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="col">
# 		<div class="CardProduct d-flex flex-column py-3 px-3
# 			CornerBtmRight2 CornerBtmRight3 ">
# 			<div class="Head">
# 				<div class="d-flex flex-row justify-content-between
# 					align-items-baseline">
# 					<a class="Subcat" href="/product-search?IDSubcat=164">
# 						Kale
# 					</a>
#
# 				</div>
#
# 				<div>
# 					<a class="Product font-size-120 font-weight-bold" href="/product/1825">
# 						Red Russian Kale - 1-lb. bunch
# 					</a>
# 				</div>
#
# 				<div>
# 					<a class="Producer" href="/about-producer/86">
# 						Raccoon Forks Farms
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class="Body flex-grow-1 mt-2 mb-1" data-target="#DlgDtlProduct1825" data-toggle="modal">
#
# 				<div style="background-image: url('/StoreImg/TUWDAPPDSB72.jpg');" class="Img rounded rounded-lg">
# 				</div>
# 			</div>
#
# 			<div class="Foot" data-target="#DlgDtlProduct1825" data-toggle="modal">
#
#
# 				<div>
# 					<div class="d-flex flex-row justify-content-between">
# 						<div>1-lb. bunch</div>
# 						<div>$5.50</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# </div>
# 	<div class="d-flex flex-row mt-3 pl-1">
# 	</div>
# </div>
#
#
# <div id="DlgDtlProduct14383" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/14383">Red Kale</a><br>
#
# Product 014383
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/238" class="font-weight-semi">
# 							Lee's Greens, LLC
# 						</a><br>
#
# Producer 0238 'lg704'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct14383">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/LZDYGJGW6SPU.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
#
#
#
#
#
#
# 	<a href="/product-search?CkNaturGrownSelf=true">Naturally grown</a>
# 	<a href="/product-search?CkIntegPestMgmtSelf=true">Integrated Pest Management</a>
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty15596" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0015596 half pound bag, Red russian kale
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$5.75
# 	</div>
# 	<div class="col text-right">
# 		2<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>Fresh cut red kale half lb bags, great for fresh eating.</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct14383">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <div id="DlgDtlProduct7986" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/7986">Blue Curled Scotch Kale</a><br>
#
# Product 007986
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/299" class="font-weight-semi">
# 							Simon's Plant Collaboration
# 						</a><br>
#
# Producer 0299 'sim14'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct7986">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/A5B5MWA9NNHX.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
#
#
#
#
#
# 	<a href="/product-search?CkNaturGrownCert=true">Certified Naturally Grown</a>
#
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty9008" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0009008 bag
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$3.50
# 	</div>
# 	<div class="col text-right">
# 		27<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>This variety of kale has curly, blue-green, tender (and delicious!) leaves. Each bag contains about 8 ounces.</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct7986">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <div id="DlgDtlProduct12294" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/12294">Green Kale</a><br>
#
# Product 012294
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/228" class="font-weight-semi">
# 							Joyful Greens
# 						</a><br>
#
# Producer 0228 'joyfl'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct12294">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/SBYK51EW02NZ.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
#
#
#
#
#
# 	<a href="/product-search?CkNaturGrownCert=true">Certified Naturally Grown</a>
#
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty13248" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0013248 bunch
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$2.50
# 	</div>
# 	<div class="col text-right">
# 		30<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>This Leafy herbaceous biennial vegetable is Sweet with an earthy bitterness flavor. It is a great addition to your favorite salad dish or pot of soup.</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct12294">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <div id="DlgDtlProduct13846" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/13846">Dinosaur Kale</a><br>
#
# Product 013846
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/228" class="font-weight-semi">
# 							Joyful Greens
# 						</a><br>
#
# Producer 0228 'joyfl'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct13846">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/ZC0PNB1ZQ35E.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
#
#
#
#
#
# 	<a href="/product-search?CkNaturGrownCert=true">Certified Naturally Grown</a>
#
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty14799" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0014799 bunch
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$3.00
# 	</div>
# 	<div class="col text-right">
# 		25<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>Dinosaur kale is a dark green leafy vegetable. The leaves are so hearty that, even when well-cooked, they retain a wonderful firm texture, making them a great choice for braising or adding to stews.</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct13846">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <div id="DlgDtlProduct8521" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/8521">Curly Green Kale New crop</a><br>
#
# Product 008521
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/287" class="font-weight-semi">
# 							Red Barn Produce
# 						</a><br>
#
# Producer 0287 'rbarn'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct8521">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/43V34MPLXXT0.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
#
#
#
#
#
#
# 	<a href="/product-search?CkNaturGrownSelf=true">Naturally grown</a>
#
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty9537" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0009537 bag
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$3.25
# 	</div>
# 	<div class="col text-right">
# 		6<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>Young curly kale.  Washed and bagged in 8 oz bag. Variety is Vates Curly. Great for soups,salads,in scrambled eggs, or in salads. Grown chemical free in our hoophouse.</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct8521">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <div id="DlgDtlProduct6483" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/6483">Red Russian Kale - Baby Leaf</a><br>
#
# Product 006483
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/299" class="font-weight-semi">
# 							Simon's Plant Collaboration
# 						</a><br>
#
# Producer 0299 'sim14'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct6483">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/0DMQG6XRR62S.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
#
#
#
#
#
# 	<a href="/product-search?CkNaturGrownCert=true">Certified Naturally Grown</a>
#
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty7528" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0007528 bag
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$4.00
# 	</div>
# 	<div class="col text-right">
# 		13<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>This tender, red stemmed kale is tasty in salads or lightly cooked. Each bag contains approximately 8 ounces of baby leaf kale.</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct6483">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <div id="DlgDtlProduct6548" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/6548">Kale: Dinosaur</a><br>
#
# Product 006548
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/137" class="font-weight-semi">
# 							Eating Well Farm
# 						</a><br>
#
# Producer 0137 'Biz14'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct6548">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/SG2QMPER4WTH.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
#
#
#
#
#
# 	<a href="/product-search?CkNaturGrownCert=true">Certified Naturally Grown</a>
#
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty7593" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0007593 bag
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$3.00
# 	</div>
# 	<div class="col text-right">
# 		8<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>Lacinato, or Dinosaur, Kale has a softer texture than curly kale and is great in raw kale salads. Each bag weighs about 8 ounces.</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct6548">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <div id="DlgDtlProduct6550" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/6550">Kale: Scarlet</a><br>
#
# Product 006550
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/137" class="font-weight-semi">
# 							Eating Well Farm
# 						</a><br>
#
# Producer 0137 'Biz14'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct6550">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/F6PVV08GJ62Q.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
#
#
#
#
#
# 	<a href="/product-search?CkNaturGrownCert=true">Certified Naturally Grown</a>
#
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty7595" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0007595 bag
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$3.00
# 	</div>
# 	<div class="col text-right">
# 		9<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>This open-pollinated variety of kale is beautiful as well as delicious! Each bag will contain about 8 ounces of Scarlet kale.</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct6550">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <div id="DlgDtlProduct8004" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/8004">Kale: Blue Curled Scotch</a><br>
#
# Product 008004
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/137" class="font-weight-semi">
# 							Eating Well Farm
# 						</a><br>
#
# Producer 0137 'Biz14'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct8004">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/QHJ3WAL436XJ.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
#
#
#
#
#
# 	<a href="/product-search?CkNaturGrownCert=true">Certified Naturally Grown</a>
#
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty9026" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0009026 bag
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$3.00
# 	</div>
# 	<div class="col text-right">
# 		10<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>This variety of kale has curly, blue-green, tender (and delicious!) leaves. Each bag contains about 8 ounces.</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct8004">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <div id="DlgDtlProduct8434" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/8434">AG Blue Dwarf Curly Kale</a><br>
#
# Product 008434
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/176" class="font-weight-semi">
# 							Early Morning Harvest
# 						</a><br>
#
# Producer 0176 'emh-1'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct8434">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/A4SYZ3KGKNT2.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
# 	<a href="/product-search?CkVegan=true">Vegan</a>
#
#
#
#
# 	<a href="/product-search?CkNaturGrownSelf=true">Naturally grown</a>
#
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty9451" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0009451 bag
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$3.00
# 	</div>
# 	<div class="col text-right">
# 		3<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>Green curled and ruffled leaves for garnish or eating. May have some imperfections as we use no herbicides, pesticides, or chemicals in our greenhouse.</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct8434">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <div id="DlgDtlProduct8627" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/8627">AG Tascano Kale</a><br>
#
# Product 008627
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/176" class="font-weight-semi">
# 							Early Morning Harvest
# 						</a><br>
#
# Producer 0176 'emh-1'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct8627">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/JPXK43Z9MQAK.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
# 	<a href="/product-search?CkVegan=true">Vegan</a>
#
#
#
#
# 	<a href="/product-search?CkNaturGrownSelf=true">Naturally grown</a>
#
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty9643" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0009643 bunch
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$3.00
# 	</div>
# 	<div class="col text-right">
# 		3<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>Extra dark green, noncurled.  Rich, tender leaves have a soft texture.  Italian heirloom. May have some imperfections as we use no herbicides, pesticides, or chemicals in our greenhouse.</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct8627">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <div id="DlgDtlProduct1825" class="DlgDtlProduct modal" role="dialog" tabindex="-1">
# 	<div class="modal-dialog
# 		modal-xl
# 		modal-dialog-centered">
# 		<div class="modal-content">
# 			<div class="modal-header d-flex justify-content-between
# 				align-items-start py-2 px-3">
#
# 				<div class="d-flex align-items-center mr-2">
# 					<div class="d-none d-lg-block mr-3">
# 						<img src="/Static/product.svg" alt="" height="40">
# 					</div>
# 					<div class="text-sm-left">
# 						<a href="/product/1825">Red Russian Kale - 1-lb. bunch</a><br>
#
# Product 001825
# 					</div>
# 				</div>
#
# 				<div class="d-flex align-items-center ml-2">
# 					<div class="text-right">
# 						<a href="/about-producer/86" class="font-weight-semi">
# 							Raccoon Forks Farms
# 						</a><br>
#
# Producer 0086 '59907'
# 					</div>
# 					<div class="d-none d-lg-block ml-3">
# 						<img src="/Static/producer.svg" alt="" width="40" height="40">
# 					</div>
# 				</div>
# 			</div>
#
# 			<div id="FlashesProduct1825">
# 			</div>
#
# 			<div class="modal-body">
# 				<div class="row">
# 					<div class="h-50 col-lg-4 mb-2 mb-lg-0">
# 						<div class="form-group mb-0">
# 							<img src="/StoreImg/TUWDAPPDSB72.jpg" alt="Product or producer image" class="w-100 border rounded p-0">
# 						</div>
# 					</div>
#
# 					<div class="col-md">
# 						<div class="text-center">
#
#
# 							<div>
# 								<a href="/product-search?IDCat=1" class="text-muted">
# 									Local Produce
# 								</a>
# 							</div>
#
# 							<div>
# 								<a href="/product-search?IDSubcat=164" class="text-muted">
# 									Kale
# 								</a>
# 							</div>
#
# 							<div class="mt-2">
#
# <div class="LinksAttrProduct">
#
#
#
#
#
#
# 	<a href="/product-search?CkNaturGrownSelf=true">Naturally grown</a>
#
#
#
#
#
#
# </div>							</div>
# 						</div>
#
# 						<div class="my-3">
#
# <div class="GridTbl Head d-none d-md-block">
# 	<div class="row font-weight-bold">
# 		<div class="col-6 col-lg-7">Variety</div>
# 		<div class="col text-right">Price</div>
# 		<div class="col text-right">Avail</div>
# 		<div class="col-2"></div>
#
# 	</div>
# </div>
# <div class="GridTbl Body">
# 	<div id="RowTblVty16449" class="Row">
#
# <div class="row align-items-center">
# 	<div class="col-md-6 col-lg-7 font-weight-semi font-weight-md-normal
# 		mb-1 mb-md-0">
# 		0016449 1-lb. bunch
# 	</div>
# 	<div class="col-5 col-sm-6 col-md text-md-right">
# 		$5.50
# 	</div>
# 	<div class="col text-right">
# 		9<span class="d-md-none"> avail</span>
# 	</div>
# 	<div class="col-3 col-sm-2 text-right">
# 		<button class="btn btn-secondary" style="font-size:12px;" disabled="">
# 			Login to Purchase
# 		</button>
# 	</div>
# </div>	</div>
# </div>						</div>
#
# 						<div class="Descrip MargP-Trim text-center mt-4 mb-2 px-sm-3
# 							px-lg-5">
# 							<p>Delicious dark green leaves with violet veining.  Wonderful raw and cooked - great in salads, soups, stir-fries, and smoothies!</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 			<div class="modal-footer p-2">
# 				<button type="button" class="btn btn-secondary ml-auto" data-toggle="modal" data-target="#DlgDtlProduct1825">Close</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# 	</main>
#
#
# 	<footer class="page-footer p-3 bg-dark text-light">
# 		<div class="d-sm-flex">
# 			<div class="d-none d-sm-block pl-1 pt-1">
# 				<a href="https://iowafood.coop/">
# 					<img class="Seal" src="/Static/logo-seal-mono.svg" alt="" width="120">
# 				</a>
# 			</div>
#
# 			<div class="flex-grow-1 ml-sm-4 mr-4">
# 				<address class="mb-sm-0">
# 					<span class="text-uppercase font-size-110">Iowa Food Cooperative</span><br>
# 					4944 Franklin Ave, Suite G<br>
# 					Des Moines, IA 50310<br>
# 					<a href="tel:+1(515)978-1034">(515)978-1034</a><br>
# 					<a href="mailto:help@iowafood.coop" target="_top">
# 						help@iowafood.coop
# 					</a>
# 				</address>
# 			</div>
#
# 			<div class="ml-auto mr-3 mr-md-3">
# 				<div class="text-uppercase font-size-110 mb-1">Links</div>
# 				<div class="d-md-flex">
# 					<div class="mr-md-4">
# 						<a href="https://iowafood.coop/">
# 							IFC Home
# 						</a><br>
# 						<a href="https://iowafood.coop/locationshours/">
# 							Pickup locations
# 						</a><br>
# 						<a href="https://iowafood.coop/ifc-shopping-calendar/">
# 							Shopping calendar
# 						</a>
# 					</div>
# 					<div>
# 						<a href="https://iowafood.coop/member-information-statement/">
# 							Terms of service
# 						</a><br>
# 						<a href="/acknowledgments">
# 							Acknowledgments
# 						</a>
# 						<br>
# 						<a href="/member-registration">
# 							Start free trial!
# 						</a>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</footer>
#
# 	<script>
# 		// Focus the name field when the Login dialog is displayed. 'autofocus' does
# 		// not work there:
# 		$("#DlgLogin").on("shown.bs.modal", function() {
# 			$("#NameLogin").trigger("focus");
# 		});
#
# 		// Shared handlers
# 		// ---------------
# 		// These handlers are re-used throughout the app.
#
# 		$("input.InputQty").on("input", Rem_ChNonQty);
# 		$("input.InputWgt").on("input", Rem_ChNonWgt);
# 	</script>
#
#
# </body></html>

# %%
for i in myDynamicElement:

  print(i.text)

  print("------------")
# Out:
# Kale
# Red Kale
# Lee's Greens, LLC
# Fresh cut red kale half lb bags, great for fresh eating.
# half pound bag, Red russian kale
# $5.75
# Kale
# Blue Curled Scotch Kale
# Simon's Plant Collaboration
# bag
# $3.50
# Kale
# Green Kale
# Joyful Greens
# bunch
# $2.50
# Kale
# Dinosaur Kale
# Joyful Greens
# bunch
# $3.00
# Kale
# Curly Green Kale New crop
# Red Barn Produce
# bag
# $3.25
# Kale
# Red Russian Kale - Baby Leaf
# Simon's Plant Collaboration
# bag
# $4.00
# Kale
# Kale: Dinosaur
# Eating Well Farm
# bag
# $3.00
# Kale
# Kale: Scarlet
# Eating Well Farm
# bag
# $3.00
# Kale
# Kale: Blue Curled Scotch
# Eating Well Farm
# bag
# $3.00
# Kale
# AG Blue Dwarf Curly Kale
# Early Morning Harvest
# bag
# $3.00
# Kale
# AG Tascano Kale
# Early Morning Harvest
# bunch
# $3.00
# Kale
# Red Russian Kale - 1-lb. bunch
# Raccoon Forks Farms
# 1-lb. bunch
# $5.50
# ------------

# %%
print(type(myDynamicElement))
# Out:
# <class 'list'>

# %%
print(myDynamicElement)
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f44094a4015f07ec83d0b5e4006d4133", element="2c1cbafd-4976-4194-887b-d6358bb7c414")>]
